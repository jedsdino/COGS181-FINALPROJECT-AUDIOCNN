# %% [markdown]
# # Convolutional Neural Networks for Audio Detection
# ## Setting Up

# %%
# copy from drive to working directory
# !cp -r /content/drive/MyDrive/COGS181_DATA /content/COGS181

# %%
# libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torchaudio
import os
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt

# %%
# audio (WAV) files
## train
train_real_path = "/content/COGS181/train_real"
train_fake_path = "/content/COGS181/train_fake"

## test
test_real_path  = "/content/COGS181/test_real"
test_fake_path  = "/content/COGS181/test_fake"

# %%
# get the files from the folder to use
def file_to_folder(folder, label):
  files = []
  labels = []
  for filename in os.listdir(folder):
    # Exclude macOS resource fork files that start with '._'
    if filename.lower().endswith(".wav") and not filename.startswith('._'):
      files.append(os.path.join(folder, filename))
      labels.append(label)
  return files, labels

# get files and labels
## train
train_real_files, train_real_labels = file_to_folder(train_real_path, 0)
train_fake_files, train_fake_labels = file_to_folder(train_fake_path, 1)


## test
test_real_files, test_real_labels = file_to_folder(test_real_path, 0)
test_fake_files, test_fake_labels = file_to_folder(test_fake_path, 1)

## combine for train, validation, and test datasets
train_files = train_real_files + train_fake_files
train_labels = train_real_labels + train_fake_labels

test_files = test_real_files + test_fake_files
test_labels = test_real_labels + test_fake_labels

len(train_files), len(test_files)
# Out:
# (3750, 1250)

# %%
# define audiodataset
class AudioDataset(Dataset):
    def __init__(self, audio_files, labels):
        self.audio_files = audio_files
        self.labels = labels
        self.transform = torchaudio.transforms.Spectrogram()

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        waveform, _ = torchaudio.load(self.audio_files[idx])
        spectrogram = self.transform(waveform)
        label = self.labels[idx]
        return spectrogram, label

# %%
# getting the train/test dataset and loader
train_dataset = AudioDataset(train_files, train_labels)
test_dataset = AudioDataset(test_files, test_labels)

train_loader = DataLoader(train_dataset, batch_size = 1, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = 1)

# %% [markdown]
# # Neural Network X
# Total layers: 6
#
# Activation function: ReLU
#
# Pooling functions: max pooling and adaptive average pool
#
# Optimization: Adam
#
# Regularization: Dropout
#
# Normalization: N/A

# %%
# audio CNN definition
class AudioCNN(nn.Module):
    def __init__(self):
        super(AudioCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size = 3, padding = 1)
        self.pool = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size = 3, padding = 1)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(64 * 1 * 1, 256)
        self.dropout = nn.Dropout(0.3)
        self.fc2 = nn.Linear(256, 2)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.avg_pool(x)
        x = x.view(-1, 64 * 1 * 1)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

model = AudioCNN()

# %%
# loss function and optimizer
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 3e-4, weight_decay = 1e-4)

# %%
# training the model
avg_losses = []
num_epochs = 10
print_freq = 100

for epoch in range(num_epochs):
    model.train()

    running_loss = 0.0
    for i, (spectrograms, labels) in enumerate(train_loader, 0):
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        optimizer.zero_grad()
        outputs = model(spectrograms)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # not in original article but added for consistency
        if i % print_freq == print_freq - 1:
          avg_loss = running_loss / print_freq
          print("[epoch: {}, i: {:5d}] avg mini-batch loss: {: .3f}".format(epoch, i, avg_loss))
          avg_losses.append(avg_loss)
          running_loss = 0.0

print("Finished Training.")
# Out:
# [epoch: 0, i:    99] avg mini-batch loss:  0.810
# [epoch: 0, i:   199] avg mini-batch loss:  0.697
# [epoch: 0, i:   299] avg mini-batch loss:  0.645
# [epoch: 0, i:   399] avg mini-batch loss:  0.609
# [epoch: 0, i:   499] avg mini-batch loss:  0.637
# [epoch: 0, i:   599] avg mini-batch loss:  0.625
# [epoch: 0, i:   699] avg mini-batch loss:  0.597
# [epoch: 0, i:   799] avg mini-batch loss:  0.584
# [epoch: 0, i:   899] avg mini-batch loss:  0.575
# [epoch: 0, i:   999] avg mini-batch loss:  0.653
# [epoch: 0, i:  1099] avg mini-batch loss:  0.607
# [epoch: 0, i:  1199] avg mini-batch loss:  0.626
# [epoch: 0, i:  1299] avg mini-batch loss:  0.606
# [epoch: 0, i:  1399] avg mini-batch loss:  0.580
# [epoch: 0, i:  1499] avg mini-batch loss:  0.578
# [epoch: 0, i:  1599] avg mini-batch loss:  0.544
# [epoch: 0, i:  1699] avg mini-batch loss:  0.591
# [epoch: 0, i:  1799] avg mini-batch loss:  0.617
# [epoch: 0, i:  1899] avg mini-batch loss:  0.570
# [epoch: 0, i:  1999] avg mini-batch loss:  0.619
# [epoch: 0, i:  2099] avg mini-batch loss:  0.611
# [epoch: 0, i:  2199] avg mini-batch loss:  0.571
# [epoch: 0, i:  2299] avg mini-batch loss:  0.571
# [epoch: 0, i:  2399] avg mini-batch loss:  0.581
# [epoch: 0, i:  2499] avg mini-batch loss:  0.618
# [epoch: 0, i:  2599] avg mini-batch loss:  0.573
# [epoch: 0, i:  2699] avg mini-batch loss:  0.646
# [epoch: 0, i:  2799] avg mini-batch loss:  0.562
# [epoch: 0, i:  2899] avg mini-batch loss:  0.579
# [epoch: 0, i:  2999] avg mini-batch loss:  0.571
# [epoch: 0, i:  3099] avg mini-batch loss:  0.643
# [epoch: 0, i:  3199] avg mini-batch loss:  0.532
# [epoch: 0, i:  3299] avg mini-batch loss:  0.500
# [epoch: 0, i:  3399] avg mini-batch loss:  0.542
# [epoch: 0, i:  3499] avg mini-batch loss:  0.557
# [epoch: 0, i:  3599] avg mini-batch loss:  0.588
# [epoch: 0, i:  3699] avg mini-batch loss:  0.502
# [epoch: 1, i:    99] avg mini-batch loss:  0.585
# [epoch: 1, i:   199] avg mini-batch loss:  0.553
# [epoch: 1, i:   299] avg mini-batch loss:  0.548
# [epoch: 1, i:   399] avg mini-batch loss:  0.583
# [epoch: 1, i:   499] avg mini-batch loss:  0.516
# [epoch: 1, i:   599] avg mini-batch loss:  0.499
# [epoch: 1, i:   699] avg mini-batch loss:  0.488
# [epoch: 1, i:   799] avg mini-batch loss:  0.539
# [epoch: 1, i:   899] avg mini-batch loss:  0.546
# [epoch: 1, i:   999] avg mini-batch loss:  0.555
# [epoch: 1, i:  1099] avg mini-batch loss:  0.532
# [epoch: 1, i:  1199] avg mini-batch loss:  0.523
# [epoch: 1, i:  1299] avg mini-batch loss:  0.493
# [epoch: 1, i:  1399] avg mini-batch loss:  0.482
# [epoch: 1, i:  1499] avg mini-batch loss:  0.545
# [epoch: 1, i:  1599] avg mini-batch loss:  0.485
# [epoch: 1, i:  1699] avg mini-batch loss:  0.509
# [epoch: 1, i:  1799] avg mini-batch loss:  0.500
# [epoch: 1, i:  1899] avg mini-batch loss:  0.518
# [epoch: 1, i:  1999] avg mini-batch loss:  0.417
# [epoch: 1, i:  2099] avg mini-batch loss:  0.445
# [epoch: 1, i:  2199] avg mini-batch loss:  0.454
# [epoch: 1, i:  2299] avg mini-batch loss:  0.473
# [epoch: 1, i:  2399] avg mini-batch loss:  0.468
# [epoch: 1, i:  2499] avg mini-batch loss:  0.444
# [epoch: 1, i:  2599] avg mini-batch loss:  0.454
# [epoch: 1, i:  2699] avg mini-batch loss:  0.657
# [epoch: 1, i:  2799] avg mini-batch loss:  0.446
# [epoch: 1, i:  2899] avg mini-batch loss:  0.438
# [epoch: 1, i:  2999] avg mini-batch loss:  0.439
# [epoch: 1, i:  3099] avg mini-batch loss:  0.488
# [epoch: 1, i:  3199] avg mini-batch loss:  0.465
# [epoch: 1, i:  3299] avg mini-batch loss:  0.436
# [epoch: 1, i:  3399] avg mini-batch loss:  0.431
# [epoch: 1, i:  3499] avg mini-batch loss:  0.441
# [epoch: 1, i:  3599] avg mini-batch loss:  0.427
# [epoch: 1, i:  3699] avg mini-batch loss:  0.513
# [epoch: 2, i:    99] avg mini-batch loss:  0.393
# [epoch: 2, i:   199] avg mini-batch loss:  0.458
# [epoch: 2, i:   299] avg mini-batch loss:  0.452
# [epoch: 2, i:   399] avg mini-batch loss:  0.447
# [epoch: 2, i:   499] avg mini-batch loss:  0.434
# [epoch: 2, i:   599] avg mini-batch loss:  0.501
# [epoch: 2, i:   699] avg mini-batch loss:  0.486
# [epoch: 2, i:   799] avg mini-batch loss:  0.401
# [epoch: 2, i:   899] avg mini-batch loss:  0.368
# [epoch: 2, i:   999] avg mini-batch loss:  0.453
# [epoch: 2, i:  1099] avg mini-batch loss:  0.415
# [epoch: 2, i:  1199] avg mini-batch loss:  0.489
# [epoch: 2, i:  1299] avg mini-batch loss:  0.635
# [epoch: 2, i:  1399] avg mini-batch loss:  0.501
# [epoch: 2, i:  1499] avg mini-batch loss:  0.439
# [epoch: 2, i:  1599] avg mini-batch loss:  0.445
# [epoch: 2, i:  1699] avg mini-batch loss:  0.333
# [epoch: 2, i:  1799] avg mini-batch loss:  0.409
# [epoch: 2, i:  1899] avg mini-batch loss:  0.370
# [epoch: 2, i:  1999] avg mini-batch loss:  0.441
# [epoch: 2, i:  2099] avg mini-batch loss:  0.392
# [epoch: 2, i:  2199] avg mini-batch loss:  0.371
# [epoch: 2, i:  2299] avg mini-batch loss:  0.468
# [epoch: 2, i:  2399] avg mini-batch loss:  0.448
# [epoch: 2, i:  2499] avg mini-batch loss:  0.375
# [epoch: 2, i:  2599] avg mini-batch loss:  0.353
# [epoch: 2, i:  2699] avg mini-batch loss:  0.387
# [epoch: 2, i:  2799] avg mini-batch loss:  0.308
# [epoch: 2, i:  2899] avg mini-batch loss:  0.411
# [epoch: 2, i:  2999] avg mini-batch loss:  0.442
# [epoch: 2, i:  3099] avg mini-batch loss:  0.413
# [epoch: 2, i:  3199] avg mini-batch loss:  0.352
# [epoch: 2, i:  3299] avg mini-batch loss:  0.391
# [epoch: 2, i:  3399] avg mini-batch loss:  0.395
# [epoch: 2, i:  3499] avg mini-batch loss:  0.466
# [epoch: 2, i:  3599] avg mini-batch loss:  0.413
# [epoch: 2, i:  3699] avg mini-batch loss:  0.411
# [epoch: 3, i:    99] avg mini-batch loss:  0.313
# [epoch: 3, i:   199] avg mini-batch loss:  0.385
# [epoch: 3, i:   299] avg mini-batch loss:  0.358
# [epoch: 3, i:   399] avg mini-batch loss:  0.474
# [epoch: 3, i:   499] avg mini-batch loss:  0.423
# [epoch: 3, i:   599] avg mini-batch loss:  0.419
# [epoch: 3, i:   699] avg mini-batch loss:  0.423
# [epoch: 3, i:   799] avg mini-batch loss:  0.498
# [epoch: 3, i:   899] avg mini-batch loss:  0.416
# [epoch: 3, i:   999] avg mini-batch loss:  0.382
# [epoch: 3, i:  1099] avg mini-batch loss:  0.326
# [epoch: 3, i:  1199] avg mini-batch loss:  0.359
# [epoch: 3, i:  1299] avg mini-batch loss:  0.380
# [epoch: 3, i:  1399] avg mini-batch loss:  0.375
# [epoch: 3, i:  1499] avg mini-batch loss:  0.322
# [epoch: 3, i:  1599] avg mini-batch loss:  0.308
# [epoch: 3, i:  1699] avg mini-batch loss:  0.408
# [epoch: 3, i:  1799] avg mini-batch loss:  0.436
# [epoch: 3, i:  1899] avg mini-batch loss:  0.397
# [epoch: 3, i:  1999] avg mini-batch loss:  0.361
# [epoch: 3, i:  2099] avg mini-batch loss:  0.293
# [epoch: 3, i:  2199] avg mini-batch loss:  0.429
# [epoch: 3, i:  2299] avg mini-batch loss:  0.411
# [epoch: 3, i:  2399] avg mini-batch loss:  0.405
# [epoch: 3, i:  2499] avg mini-batch loss:  0.351
# [epoch: 3, i:  2599] avg mini-batch loss:  0.387
# [epoch: 3, i:  2699] avg mini-batch loss:  0.385
# [epoch: 3, i:  2799] avg mini-batch loss:  0.442
# [epoch: 3, i:  2899] avg mini-batch loss:  0.428
# [epoch: 3, i:  2999] avg mini-batch loss:  0.402
# [epoch: 3, i:  3099] avg mini-batch loss:  0.370
# [epoch: 3, i:  3199] avg mini-batch loss:  0.338
# [epoch: 3, i:  3299] avg mini-batch loss:  0.377
# [epoch: 3, i:  3399] avg mini-batch loss:  0.345
# [epoch: 3, i:  3499] avg mini-batch loss:  0.367
# [epoch: 3, i:  3599] avg mini-batch loss:  0.513
# [epoch: 3, i:  3699] avg mini-batch loss:  0.375
# [epoch: 4, i:    99] avg mini-batch loss:  0.359
# [epoch: 4, i:   199] avg mini-batch loss:  0.347
# [epoch: 4, i:   299] avg mini-batch loss:  0.409
# [epoch: 4, i:   399] avg mini-batch loss:  0.377
# [epoch: 4, i:   499] avg mini-batch loss:  0.347
# [epoch: 4, i:   599] avg mini-batch loss:  0.384
# [epoch: 4, i:   699] avg mini-batch loss:  0.397
# [epoch: 4, i:   799] avg mini-batch loss:  0.337
# [epoch: 4, i:   899] avg mini-batch loss:  0.334
# [epoch: 4, i:   999] avg mini-batch loss:  0.368
# [epoch: 4, i:  1099] avg mini-batch loss:  0.423
# [epoch: 4, i:  1199] avg mini-batch loss:  0.337
# [epoch: 4, i:  1299] avg mini-batch loss:  0.392
# [epoch: 4, i:  1399] avg mini-batch loss:  0.258
# [epoch: 4, i:  1499] avg mini-batch loss:  0.307
# [epoch: 4, i:  1599] avg mini-batch loss:  0.350
# [epoch: 4, i:  1699] avg mini-batch loss:  0.405
# [epoch: 4, i:  1799] avg mini-batch loss:  0.336
# [epoch: 4, i:  1899] avg mini-batch loss:  0.342
# [epoch: 4, i:  1999] avg mini-batch loss:  0.385
# [epoch: 4, i:  2099] avg mini-batch loss:  0.321
# [epoch: 4, i:  2199] avg mini-batch loss:  0.368
# [epoch: 4, i:  2299] avg mini-batch loss:  0.410
# [epoch: 4, i:  2399] avg mini-batch loss:  0.299
# [epoch: 4, i:  2499] avg mini-batch loss:  0.341
# [epoch: 4, i:  2599] avg mini-batch loss:  0.352
# [epoch: 4, i:  2699] avg mini-batch loss:  0.316
# [epoch: 4, i:  2799] avg mini-batch loss:  0.292
# [epoch: 4, i:  2899] avg mini-batch loss:  0.384
# [epoch: 4, i:  2999] avg mini-batch loss:  0.290
# [epoch: 4, i:  3099] avg mini-batch loss:  0.312
# [epoch: 4, i:  3199] avg mini-batch loss:  0.303
# [epoch: 4, i:  3299] avg mini-batch loss:  0.449
# [epoch: 4, i:  3399] avg mini-batch loss:  0.348
# [epoch: 4, i:  3499] avg mini-batch loss:  0.417
# [epoch: 4, i:  3599] avg mini-batch loss:  0.336
# [epoch: 4, i:  3699] avg mini-batch loss:  0.351
# [epoch: 5, i:    99] avg mini-batch loss:  0.302
# [epoch: 5, i:   199] avg mini-batch loss:  0.340
# [epoch: 5, i:   299] avg mini-batch loss:  0.342
# [epoch: 5, i:   399] avg mini-batch loss:  0.336
# [epoch: 5, i:   499] avg mini-batch loss:  0.386
# [epoch: 5, i:   599] avg mini-batch loss:  0.289
# [epoch: 5, i:   699] avg mini-batch loss:  0.313
# [epoch: 5, i:   799] avg mini-batch loss:  0.288
# [epoch: 5, i:   899] avg mini-batch loss:  0.318
# [epoch: 5, i:   999] avg mini-batch loss:  0.269
# [epoch: 5, i:  1099] avg mini-batch loss:  0.330
# [epoch: 5, i:  1199] avg mini-batch loss:  0.411
# [epoch: 5, i:  1299] avg mini-batch loss:  0.291
# [epoch: 5, i:  1399] avg mini-batch loss:  0.341
# [epoch: 5, i:  1499] avg mini-batch loss:  0.323
# [epoch: 5, i:  1599] avg mini-batch loss:  0.318
# [epoch: 5, i:  1699] avg mini-batch loss:  0.372
# [epoch: 5, i:  1799] avg mini-batch loss:  0.285
# [epoch: 5, i:  1899] avg mini-batch loss:  0.274
# [epoch: 5, i:  1999] avg mini-batch loss:  0.335
# [epoch: 5, i:  2099] avg mini-batch loss:  0.366
# [epoch: 5, i:  2199] avg mini-batch loss:  0.260
# [epoch: 5, i:  2299] avg mini-batch loss:  0.271
# [epoch: 5, i:  2399] avg mini-batch loss:  0.308
# [epoch: 5, i:  2499] avg mini-batch loss:  0.289
# [epoch: 5, i:  2599] avg mini-batch loss:  0.252
# [epoch: 5, i:  2699] avg mini-batch loss:  0.322
# [epoch: 5, i:  2799] avg mini-batch loss:  0.380
# [epoch: 5, i:  2899] avg mini-batch loss:  0.240
# [epoch: 5, i:  2999] avg mini-batch loss:  0.235
# [epoch: 5, i:  3099] avg mini-batch loss:  0.292
# [epoch: 5, i:  3199] avg mini-batch loss:  0.249
# [epoch: 5, i:  3299] avg mini-batch loss:  0.274
# [epoch: 5, i:  3399] avg mini-batch loss:  0.304
# [epoch: 5, i:  3499] avg mini-batch loss:  0.277
# [epoch: 5, i:  3599] avg mini-batch loss:  0.273
# [epoch: 5, i:  3699] avg mini-batch loss:  0.287
# [epoch: 6, i:    99] avg mini-batch loss:  0.259
# [epoch: 6, i:   199] avg mini-batch loss:  0.330
# [epoch: 6, i:   299] avg mini-batch loss:  0.258
# [epoch: 6, i:   399] avg mini-batch loss:  0.333
# [epoch: 6, i:   499] avg mini-batch loss:  0.315
# [epoch: 6, i:   599] avg mini-batch loss:  0.301
# [epoch: 6, i:   699] avg mini-batch loss:  0.204
# [epoch: 6, i:   799] avg mini-batch loss:  0.242
# [epoch: 6, i:   899] avg mini-batch loss:  0.273
# [epoch: 6, i:   999] avg mini-batch loss:  0.275
# [epoch: 6, i:  1099] avg mini-batch loss:  0.285
# [epoch: 6, i:  1199] avg mini-batch loss:  0.360
# [epoch: 6, i:  1299] avg mini-batch loss:  0.309
# [epoch: 6, i:  1399] avg mini-batch loss:  0.252
# [epoch: 6, i:  1499] avg mini-batch loss:  0.213
# [epoch: 6, i:  1599] avg mini-batch loss:  0.248
# [epoch: 6, i:  1699] avg mini-batch loss:  0.176
# [epoch: 6, i:  1799] avg mini-batch loss:  0.200
# [epoch: 6, i:  1899] avg mini-batch loss:  0.218
# [epoch: 6, i:  1999] avg mini-batch loss:  0.176
# [epoch: 6, i:  2099] avg mini-batch loss:  0.266
# [epoch: 6, i:  2199] avg mini-batch loss:  0.209
# [epoch: 6, i:  2299] avg mini-batch loss:  0.190
# [epoch: 6, i:  2399] avg mini-batch loss:  0.301
# [epoch: 6, i:  2499] avg mini-batch loss:  0.251
# [epoch: 6, i:  2599] avg mini-batch loss:  0.238
# [epoch: 6, i:  2699] avg mini-batch loss:  0.175
# [epoch: 6, i:  2799] avg mini-batch loss:  0.243
# [epoch: 6, i:  2899] avg mini-batch loss:  0.202
# [epoch: 6, i:  2999] avg mini-batch loss:  0.228
# [epoch: 6, i:  3099] avg mini-batch loss:  0.155
# [epoch: 6, i:  3199] avg mini-batch loss:  0.261
# [epoch: 6, i:  3299] avg mini-batch loss:  0.252
# [epoch: 6, i:  3399] avg mini-batch loss:  0.263
# [epoch: 6, i:  3499] avg mini-batch loss:  0.241
# [epoch: 6, i:  3599] avg mini-batch loss:  0.165
# [epoch: 6, i:  3699] avg mini-batch loss:  0.166
# [epoch: 7, i:    99] avg mini-batch loss:  0.236
# [epoch: 7, i:   199] avg mini-batch loss:  0.176
# [epoch: 7, i:   299] avg mini-batch loss:  0.190
# [epoch: 7, i:   399] avg mini-batch loss:  0.210
# [epoch: 7, i:   499] avg mini-batch loss:  0.211
# [epoch: 7, i:   599] avg mini-batch loss:  0.258
# [epoch: 7, i:   699] avg mini-batch loss:  0.188
# [epoch: 7, i:   799] avg mini-batch loss:  0.196
# [epoch: 7, i:   899] avg mini-batch loss:  0.289
# [epoch: 7, i:   999] avg mini-batch loss:  0.270
# [epoch: 7, i:  1099] avg mini-batch loss:  0.195
# [epoch: 7, i:  1199] avg mini-batch loss:  0.243
# [epoch: 7, i:  1299] avg mini-batch loss:  0.212
# [epoch: 7, i:  1399] avg mini-batch loss:  0.192
# [epoch: 7, i:  1499] avg mini-batch loss:  0.216
# [epoch: 7, i:  1599] avg mini-batch loss:  0.211
# [epoch: 7, i:  1699] avg mini-batch loss:  0.176
# [epoch: 7, i:  1799] avg mini-batch loss:  0.161
# [epoch: 7, i:  1899] avg mini-batch loss:  0.202
# [epoch: 7, i:  1999] avg mini-batch loss:  0.392
# [epoch: 7, i:  2099] avg mini-batch loss:  0.232
# [epoch: 7, i:  2199] avg mini-batch loss:  0.192
# [epoch: 7, i:  2299] avg mini-batch loss:  0.231
# [epoch: 7, i:  2399] avg mini-batch loss:  0.153
# [epoch: 7, i:  2499] avg mini-batch loss:  0.137
# [epoch: 7, i:  2599] avg mini-batch loss:  0.161
# [epoch: 7, i:  2699] avg mini-batch loss:  0.143
# [epoch: 7, i:  2799] avg mini-batch loss:  0.113
# [epoch: 7, i:  2899] avg mini-batch loss:  0.196
# [epoch: 7, i:  2999] avg mini-batch loss:  0.203
# [epoch: 7, i:  3099] avg mini-batch loss:  0.391
# [epoch: 7, i:  3199] avg mini-batch loss:  0.176
# [epoch: 7, i:  3299] avg mini-batch loss:  0.145
# [epoch: 7, i:  3399] avg mini-batch loss:  0.163
# [epoch: 7, i:  3499] avg mini-batch loss:  0.129
# [epoch: 7, i:  3599] avg mini-batch loss:  0.164
# [epoch: 7, i:  3699] avg mini-batch loss:  0.185
# [epoch: 8, i:    99] avg mini-batch loss:  0.208
# [epoch: 8, i:   199] avg mini-batch loss:  0.212
# [epoch: 8, i:   299] avg mini-batch loss:  0.174
# [epoch: 8, i:   399] avg mini-batch loss:  0.176
# [epoch: 8, i:   499] avg mini-batch loss:  0.081
# [epoch: 8, i:   599] avg mini-batch loss:  0.119
# [epoch: 8, i:   699] avg mini-batch loss:  0.240
# [epoch: 8, i:   799] avg mini-batch loss:  0.143
# [epoch: 8, i:   899] avg mini-batch loss:  0.131
# [epoch: 8, i:   999] avg mini-batch loss:  0.133
# [epoch: 8, i:  1099] avg mini-batch loss:  0.126
# [epoch: 8, i:  1199] avg mini-batch loss:  0.125
# [epoch: 8, i:  1299] avg mini-batch loss:  0.120
# [epoch: 8, i:  1399] avg mini-batch loss:  0.161
# [epoch: 8, i:  1499] avg mini-batch loss:  0.142
# [epoch: 8, i:  1599] avg mini-batch loss:  0.164
# [epoch: 8, i:  1699] avg mini-batch loss:  0.186
# [epoch: 8, i:  1799] avg mini-batch loss:  0.168
# [epoch: 8, i:  1899] avg mini-batch loss:  0.124
# [epoch: 8, i:  1999] avg mini-batch loss:  0.145
# [epoch: 8, i:  2099] avg mini-batch loss:  0.121
# [epoch: 8, i:  2199] avg mini-batch loss:  0.137
# [epoch: 8, i:  2299] avg mini-batch loss:  0.238
# [epoch: 8, i:  2399] avg mini-batch loss:  0.130
# [epoch: 8, i:  2499] avg mini-batch loss:  0.216
# [epoch: 8, i:  2599] avg mini-batch loss:  0.104
# [epoch: 8, i:  2699] avg mini-batch loss:  0.150
# [epoch: 8, i:  2799] avg mini-batch loss:  0.268
# [epoch: 8, i:  2899] avg mini-batch loss:  0.627
# [epoch: 8, i:  2999] avg mini-batch loss:  0.131
# [epoch: 8, i:  3099] avg mini-batch loss:  0.164
# [epoch: 8, i:  3199] avg mini-batch loss:  0.162
# [epoch: 8, i:  3299] avg mini-batch loss:  0.099
# [epoch: 8, i:  3399] avg mini-batch loss:  0.131
# [epoch: 8, i:  3499] avg mini-batch loss:  0.103
# [epoch: 8, i:  3599] avg mini-batch loss:  0.105
# [epoch: 8, i:  3699] avg mini-batch loss:  0.117
# [epoch: 9, i:    99] avg mini-batch loss:  0.157
# [epoch: 9, i:   199] avg mini-batch loss:  0.175
# [epoch: 9, i:   299] avg mini-batch loss:  0.103
# [epoch: 9, i:   399] avg mini-batch loss:  0.134
# [epoch: 9, i:   499] avg mini-batch loss:  0.146
# [epoch: 9, i:   599] avg mini-batch loss:  0.145
# [epoch: 9, i:   699] avg mini-batch loss:  0.103
# [epoch: 9, i:   799] avg mini-batch loss:  0.203
# [epoch: 9, i:   899] avg mini-batch loss:  0.125
# [epoch: 9, i:   999] avg mini-batch loss:  0.140
# [epoch: 9, i:  1099] avg mini-batch loss:  0.134
# [epoch: 9, i:  1199] avg mini-batch loss:  0.077
# [epoch: 9, i:  1299] avg mini-batch loss:  0.102
# [epoch: 9, i:  1399] avg mini-batch loss:  0.176
# [epoch: 9, i:  1499] avg mini-batch loss:  0.138
# [epoch: 9, i:  1599] avg mini-batch loss:  0.105
# [epoch: 9, i:  1699] avg mini-batch loss:  0.160
# [epoch: 9, i:  1799] avg mini-batch loss:  0.113
# [epoch: 9, i:  1899] avg mini-batch loss:  0.059
# [epoch: 9, i:  1999] avg mini-batch loss:  0.093
# [epoch: 9, i:  2099] avg mini-batch loss:  0.139
# [epoch: 9, i:  2199] avg mini-batch loss:  0.102
# [epoch: 9, i:  2299] avg mini-batch loss:  0.110
# [epoch: 9, i:  2399] avg mini-batch loss:  0.072
# [epoch: 9, i:  2499] avg mini-batch loss:  0.103
# [epoch: 9, i:  2599] avg mini-batch loss:  0.097
# [epoch: 9, i:  2699] avg mini-batch loss:  0.120
# [epoch: 9, i:  2799] avg mini-batch loss:  0.131
# [epoch: 9, i:  2899] avg mini-batch loss:  0.118
# [epoch: 9, i:  2999] avg mini-batch loss:  0.121
# [epoch: 9, i:  3099] avg mini-batch loss:  0.141
# [epoch: 9, i:  3199] avg mini-batch loss:  0.088
# [epoch: 9, i:  3299] avg mini-batch loss:  0.053
# [epoch: 9, i:  3399] avg mini-batch loss:  0.161
# [epoch: 9, i:  3499] avg mini-batch loss:  0.071
# [epoch: 9, i:  3599] avg mini-batch loss:  0.159
# [epoch: 9, i:  3699] avg mini-batch loss:  0.081
# Finished Training.

# %%
# training loss curve
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# test the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for spectrograms, labels in test_loader:
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        outputs = model(spectrograms)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Accuracy: 68.8%
