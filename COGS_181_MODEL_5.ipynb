# %% [markdown]
# # Convolutional Neural Networks for Audio Detection
# ## Setting Up

# %%
# copy from drive to working directory
# !cp -r /content/drive/MyDrive/COGS181_DATA /content/COGS181

# %%
# libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torchaudio
import os
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt

# %%
# audio (WAV) files
## train
train_real_path = "/content/COGS181/train_real"
train_fake_path = "/content/COGS181/train_fake"

## test
test_real_path  = "/content/COGS181/test_real"
test_fake_path  = "/content/COGS181/test_fake"

# %%
# get the files from the folder to use
def file_to_folder(folder, label):
  files = []
  labels = []
  for filename in os.listdir(folder):
    # Exclude macOS resource fork files that start with '._'
    if filename.lower().endswith(".wav") and not filename.startswith('._'):
      files.append(os.path.join(folder, filename))
      labels.append(label)
  return files, labels

# get files and labels
## train
train_real_files, train_real_labels = file_to_folder(train_real_path, 0)
train_fake_files, train_fake_labels = file_to_folder(train_fake_path, 1)


## test
test_real_files, test_real_labels = file_to_folder(test_real_path, 0)
test_fake_files, test_fake_labels = file_to_folder(test_fake_path, 1)

## combine for train, validation, and test datasets
train_files = train_real_files + train_fake_files
train_labels = train_real_labels + train_fake_labels

test_files = test_real_files + test_fake_files
test_labels = test_real_labels + test_fake_labels

len(train_files), len(test_files)
# Out:
# (3750, 1250)

# %%
# define audiodataset
class AudioDataset(Dataset):
    def __init__(self, audio_files, labels):
        self.audio_files = audio_files
        self.labels = labels
        self.transform = torchaudio.transforms.Spectrogram()

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        waveform, _ = torchaudio.load(self.audio_files[idx])
        spectrogram = self.transform(waveform)
        label = self.labels[idx]
        return spectrogram, label

# %%
# getting the train/test dataset and loader
train_dataset = AudioDataset(train_files, train_labels)
test_dataset = AudioDataset(test_files, test_labels)

train_loader = DataLoader(train_dataset, batch_size = 1, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = 1)

# %% [markdown]
# # Neural Network V
# Total layers: 5
#
# Activation function: leaky ReLU
#
# Pooling functions: max pooling, adaptive average pool
#
# Optimization: Adam
#
# Regularization: Dropout
#
# Normalization: N/A

# %%
class AudioCNN(nn.Module):
    def __init__(self):
        super(AudioCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size = 3, padding = 1)
        self.pool = nn.MaxPool2d(2)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.leaky_relu = nn.LeakyReLU() 
        self.fc1 = nn.Linear(16 * 1 * 1, 128)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(self.leaky_relu(self.conv1(x)))
        x = self.avg_pool(x)
        x = x.view(-1, 16 * 1 * 1)
        x = self.leaky_relu(self.fc1(x)) 
        x = self.dropout(x)
        x = self.fc2(x)
        return x

model = AudioCNN()

# %%
# loss function and optimizer
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

# %%
# training the model
avg_losses = []
num_epochs = 10
print_freq = 100

for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (spectrograms, labels) in enumerate(train_loader, 0):
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        optimizer.zero_grad()
        outputs = model(spectrograms)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # not in original article but added for consistency
        if i % print_freq == print_freq - 1:
          avg_loss = running_loss / print_freq
          print("[epoch: {}, i: {:5d}] avg mini-batch loss: {: .3f}".format(epoch, i, avg_loss))
          avg_losses.append(avg_loss)
          running_loss = 0.0

print("Finished Training.")
# Out:
# [epoch: 0, i:    99] avg mini-batch loss:  1.137
# [epoch: 0, i:   199] avg mini-batch loss:  1.288
# [epoch: 0, i:   299] avg mini-batch loss:  1.419
# [epoch: 0, i:   399] avg mini-batch loss:  1.210
# [epoch: 0, i:   499] avg mini-batch loss:  1.536
# [epoch: 0, i:   599] avg mini-batch loss:  1.187
# [epoch: 0, i:   699] avg mini-batch loss:  1.118
# [epoch: 0, i:   799] avg mini-batch loss:  1.156
# [epoch: 0, i:   899] avg mini-batch loss:  0.983
# [epoch: 0, i:   999] avg mini-batch loss:  1.690
# [epoch: 0, i:  1099] avg mini-batch loss:  0.858
# [epoch: 0, i:  1199] avg mini-batch loss:  1.376
# [epoch: 0, i:  1299] avg mini-batch loss:  1.482
# [epoch: 0, i:  1399] avg mini-batch loss:  1.372
# [epoch: 0, i:  1499] avg mini-batch loss:  1.171
# [epoch: 0, i:  1599] avg mini-batch loss:  1.165
# [epoch: 0, i:  1699] avg mini-batch loss:  1.573
# [epoch: 0, i:  1799] avg mini-batch loss:  1.084
# [epoch: 0, i:  1899] avg mini-batch loss:  1.172
# [epoch: 0, i:  1999] avg mini-batch loss:  1.290
# [epoch: 0, i:  2099] avg mini-batch loss:  1.274
# [epoch: 0, i:  2199] avg mini-batch loss:  1.349
# [epoch: 0, i:  2299] avg mini-batch loss:  1.257
# [epoch: 0, i:  2399] avg mini-batch loss:  1.099
# [epoch: 0, i:  2499] avg mini-batch loss:  1.580
# [epoch: 0, i:  2599] avg mini-batch loss:  1.584
# [epoch: 0, i:  2699] avg mini-batch loss:  1.063
# [epoch: 0, i:  2799] avg mini-batch loss:  1.894
# [epoch: 0, i:  2899] avg mini-batch loss:  1.007
# [epoch: 0, i:  2999] avg mini-batch loss:  1.330
# [epoch: 0, i:  3099] avg mini-batch loss:  1.383
# [epoch: 0, i:  3199] avg mini-batch loss:  1.450
# [epoch: 0, i:  3299] avg mini-batch loss:  1.160
# [epoch: 0, i:  3399] avg mini-batch loss:  1.342
# [epoch: 0, i:  3499] avg mini-batch loss:  1.658
# [epoch: 0, i:  3599] avg mini-batch loss:  1.185
# [epoch: 0, i:  3699] avg mini-batch loss:  1.408
# [epoch: 1, i:    99] avg mini-batch loss:  1.201
# [epoch: 1, i:   199] avg mini-batch loss:  1.103
# [epoch: 1, i:   299] avg mini-batch loss:  1.246
# [epoch: 1, i:   399] avg mini-batch loss:  1.682
# [epoch: 1, i:   499] avg mini-batch loss:  1.608
# [epoch: 1, i:   599] avg mini-batch loss:  1.248
# [epoch: 1, i:   699] avg mini-batch loss:  1.395
# [epoch: 1, i:   799] avg mini-batch loss:  1.450
# [epoch: 1, i:   899] avg mini-batch loss:  1.262
# [epoch: 1, i:   999] avg mini-batch loss:  1.581
# [epoch: 1, i:  1099] avg mini-batch loss:  1.332
# [epoch: 1, i:  1199] avg mini-batch loss:  1.302
# [epoch: 1, i:  1299] avg mini-batch loss:  0.917
# [epoch: 1, i:  1399] avg mini-batch loss:  0.903
# [epoch: 1, i:  1499] avg mini-batch loss:  1.065
# [epoch: 1, i:  1599] avg mini-batch loss:  1.046
# [epoch: 1, i:  1699] avg mini-batch loss:  1.400
# [epoch: 1, i:  1799] avg mini-batch loss:  1.534
# [epoch: 1, i:  1899] avg mini-batch loss:  1.592
# [epoch: 1, i:  1999] avg mini-batch loss:  1.217
# [epoch: 1, i:  2099] avg mini-batch loss:  1.276
# [epoch: 1, i:  2199] avg mini-batch loss:  1.273
# [epoch: 1, i:  2299] avg mini-batch loss:  0.906
# [epoch: 1, i:  2399] avg mini-batch loss:  1.449
# [epoch: 1, i:  2499] avg mini-batch loss:  1.528
# [epoch: 1, i:  2599] avg mini-batch loss:  1.233
# [epoch: 1, i:  2699] avg mini-batch loss:  1.162
# [epoch: 1, i:  2799] avg mini-batch loss:  1.425
# [epoch: 1, i:  2899] avg mini-batch loss:  1.324
# [epoch: 1, i:  2999] avg mini-batch loss:  1.169
# [epoch: 1, i:  3099] avg mini-batch loss:  1.310
# [epoch: 1, i:  3199] avg mini-batch loss:  1.423
# [epoch: 1, i:  3299] avg mini-batch loss:  1.453
# [epoch: 1, i:  3399] avg mini-batch loss:  1.127
# [epoch: 1, i:  3499] avg mini-batch loss:  1.807
# [epoch: 1, i:  3599] avg mini-batch loss:  1.394
# [epoch: 1, i:  3699] avg mini-batch loss:  1.515
# [epoch: 2, i:    99] avg mini-batch loss:  0.965
# [epoch: 2, i:   199] avg mini-batch loss:  1.369
# [epoch: 2, i:   299] avg mini-batch loss:  1.429
# [epoch: 2, i:   399] avg mini-batch loss:  1.158
# [epoch: 2, i:   499] avg mini-batch loss:  1.311
# [epoch: 2, i:   599] avg mini-batch loss:  0.950
# [epoch: 2, i:   699] avg mini-batch loss:  1.247
# [epoch: 2, i:   799] avg mini-batch loss:  1.597
# [epoch: 2, i:   899] avg mini-batch loss:  1.206
# [epoch: 2, i:   999] avg mini-batch loss:  1.106
# [epoch: 2, i:  1099] avg mini-batch loss:  1.251
# [epoch: 2, i:  1199] avg mini-batch loss:  1.687
# [epoch: 2, i:  1299] avg mini-batch loss:  1.287
# [epoch: 2, i:  1399] avg mini-batch loss:  1.318
# [epoch: 2, i:  1499] avg mini-batch loss:  1.073
# [epoch: 2, i:  1599] avg mini-batch loss:  1.533
# [epoch: 2, i:  1699] avg mini-batch loss:  0.963
# [epoch: 2, i:  1799] avg mini-batch loss:  1.134
# [epoch: 2, i:  1899] avg mini-batch loss:  1.085
# [epoch: 2, i:  1999] avg mini-batch loss:  1.083
# [epoch: 2, i:  2099] avg mini-batch loss:  1.600
# [epoch: 2, i:  2199] avg mini-batch loss:  1.184
# [epoch: 2, i:  2299] avg mini-batch loss:  1.470
# [epoch: 2, i:  2399] avg mini-batch loss:  1.147
# [epoch: 2, i:  2499] avg mini-batch loss:  1.337
# [epoch: 2, i:  2599] avg mini-batch loss:  1.365
# [epoch: 2, i:  2699] avg mini-batch loss:  1.408
# [epoch: 2, i:  2799] avg mini-batch loss:  1.127
# [epoch: 2, i:  2899] avg mini-batch loss:  1.529
# [epoch: 2, i:  2999] avg mini-batch loss:  1.272
# [epoch: 2, i:  3099] avg mini-batch loss:  1.173
# [epoch: 2, i:  3199] avg mini-batch loss:  1.186
# [epoch: 2, i:  3299] avg mini-batch loss:  1.565
# [epoch: 2, i:  3399] avg mini-batch loss:  1.156
# [epoch: 2, i:  3499] avg mini-batch loss:  1.559
# [epoch: 2, i:  3599] avg mini-batch loss:  1.149
# [epoch: 2, i:  3699] avg mini-batch loss:  1.607
# [epoch: 3, i:    99] avg mini-batch loss:  1.378
# [epoch: 3, i:   199] avg mini-batch loss:  1.262
# [epoch: 3, i:   299] avg mini-batch loss:  1.314
# [epoch: 3, i:   399] avg mini-batch loss:  1.349
# [epoch: 3, i:   499] avg mini-batch loss:  1.232
# [epoch: 3, i:   599] avg mini-batch loss:  1.279
# [epoch: 3, i:   699] avg mini-batch loss:  1.207
# [epoch: 3, i:   799] avg mini-batch loss:  1.320
# [epoch: 3, i:   899] avg mini-batch loss:  1.343
# [epoch: 3, i:   999] avg mini-batch loss:  1.176
# [epoch: 3, i:  1099] avg mini-batch loss:  1.083
# [epoch: 3, i:  1199] avg mini-batch loss:  1.067
# [epoch: 3, i:  1299] avg mini-batch loss:  1.039
# [epoch: 3, i:  1399] avg mini-batch loss:  1.239
# [epoch: 3, i:  1499] avg mini-batch loss:  1.625
# [epoch: 3, i:  1599] avg mini-batch loss:  1.221
# [epoch: 3, i:  1699] avg mini-batch loss:  1.406
# [epoch: 3, i:  1799] avg mini-batch loss:  1.518
# [epoch: 3, i:  1899] avg mini-batch loss:  1.314
# [epoch: 3, i:  1999] avg mini-batch loss:  1.297
# [epoch: 3, i:  2099] avg mini-batch loss:  1.308
# [epoch: 3, i:  2199] avg mini-batch loss:  1.478
# [epoch: 3, i:  2299] avg mini-batch loss:  1.575
# [epoch: 3, i:  2399] avg mini-batch loss:  1.086
# [epoch: 3, i:  2499] avg mini-batch loss:  1.300
# [epoch: 3, i:  2599] avg mini-batch loss:  1.704
# [epoch: 3, i:  2699] avg mini-batch loss:  1.358
# [epoch: 3, i:  2799] avg mini-batch loss:  1.045
# [epoch: 3, i:  2899] avg mini-batch loss:  1.401
# [epoch: 3, i:  2999] avg mini-batch loss:  1.256
# [epoch: 3, i:  3099] avg mini-batch loss:  1.484
# [epoch: 3, i:  3199] avg mini-batch loss:  1.461
# [epoch: 3, i:  3299] avg mini-batch loss:  1.346
# [epoch: 3, i:  3399] avg mini-batch loss:  1.690
# [epoch: 3, i:  3499] avg mini-batch loss:  1.239
# [epoch: 3, i:  3599] avg mini-batch loss:  1.186
# [epoch: 3, i:  3699] avg mini-batch loss:  1.078
# [epoch: 4, i:    99] avg mini-batch loss:  1.167
# [epoch: 4, i:   199] avg mini-batch loss:  0.884
# [epoch: 4, i:   299] avg mini-batch loss:  1.325
# [epoch: 4, i:   399] avg mini-batch loss:  1.399
# [epoch: 4, i:   499] avg mini-batch loss:  1.292
# [epoch: 4, i:   599] avg mini-batch loss:  1.660
# [epoch: 4, i:   699] avg mini-batch loss:  1.177
# [epoch: 4, i:   799] avg mini-batch loss:  1.548
# [epoch: 4, i:   899] avg mini-batch loss:  1.176
# [epoch: 4, i:   999] avg mini-batch loss:  1.157
# [epoch: 4, i:  1099] avg mini-batch loss:  1.234
# [epoch: 4, i:  1199] avg mini-batch loss:  1.488
# [epoch: 4, i:  1299] avg mini-batch loss:  1.092
# [epoch: 4, i:  1399] avg mini-batch loss:  1.219
# [epoch: 4, i:  1499] avg mini-batch loss:  1.493
# [epoch: 4, i:  1599] avg mini-batch loss:  1.070
# [epoch: 4, i:  1699] avg mini-batch loss:  1.230
# [epoch: 4, i:  1799] avg mini-batch loss:  1.352
# [epoch: 4, i:  1899] avg mini-batch loss:  1.671
# [epoch: 4, i:  1999] avg mini-batch loss:  1.515
# [epoch: 4, i:  2099] avg mini-batch loss:  1.013
# [epoch: 4, i:  2199] avg mini-batch loss:  1.608
# [epoch: 4, i:  2299] avg mini-batch loss:  1.189
# [epoch: 4, i:  2399] avg mini-batch loss:  1.126
# [epoch: 4, i:  2499] avg mini-batch loss:  1.235
# [epoch: 4, i:  2599] avg mini-batch loss:  1.823
# [epoch: 4, i:  2699] avg mini-batch loss:  1.313
# [epoch: 4, i:  2799] avg mini-batch loss:  1.452
# [epoch: 4, i:  2899] avg mini-batch loss:  1.240
# [epoch: 4, i:  2999] avg mini-batch loss:  1.581
# [epoch: 4, i:  3099] avg mini-batch loss:  1.132
# [epoch: 4, i:  3199] avg mini-batch loss:  0.969
# [epoch: 4, i:  3299] avg mini-batch loss:  1.187
# [epoch: 4, i:  3399] avg mini-batch loss:  1.176
# [epoch: 4, i:  3499] avg mini-batch loss:  1.398
# [epoch: 4, i:  3599] avg mini-batch loss:  1.320
# [epoch: 4, i:  3699] avg mini-batch loss:  1.141
# [epoch: 5, i:    99] avg mini-batch loss:  1.520
# [epoch: 5, i:   199] avg mini-batch loss:  1.399
# [epoch: 5, i:   299] avg mini-batch loss:  1.397
# [epoch: 5, i:   399] avg mini-batch loss:  1.430
# [epoch: 5, i:   499] avg mini-batch loss:  1.016
# [epoch: 5, i:   599] avg mini-batch loss:  1.667
# [epoch: 5, i:   699] avg mini-batch loss:  1.505
# [epoch: 5, i:   799] avg mini-batch loss:  1.285
# [epoch: 5, i:   899] avg mini-batch loss:  1.361
# [epoch: 5, i:   999] avg mini-batch loss:  1.415
# [epoch: 5, i:  1099] avg mini-batch loss:  1.112
# [epoch: 5, i:  1199] avg mini-batch loss:  1.077
# [epoch: 5, i:  1299] avg mini-batch loss:  1.126
# [epoch: 5, i:  1399] avg mini-batch loss:  1.007
# [epoch: 5, i:  1499] avg mini-batch loss:  1.086
# [epoch: 5, i:  1599] avg mini-batch loss:  1.296
# [epoch: 5, i:  1699] avg mini-batch loss:  1.137
# [epoch: 5, i:  1799] avg mini-batch loss:  1.227
# [epoch: 5, i:  1899] avg mini-batch loss:  1.376
# [epoch: 5, i:  1999] avg mini-batch loss:  1.459
# [epoch: 5, i:  2099] avg mini-batch loss:  1.245
# [epoch: 5, i:  2199] avg mini-batch loss:  1.334
# [epoch: 5, i:  2299] avg mini-batch loss:  1.581
# [epoch: 5, i:  2399] avg mini-batch loss:  1.535
# [epoch: 5, i:  2499] avg mini-batch loss:  1.806
# [epoch: 5, i:  2599] avg mini-batch loss:  1.284
# [epoch: 5, i:  2699] avg mini-batch loss:  0.966
# [epoch: 5, i:  2799] avg mini-batch loss:  0.866
# [epoch: 5, i:  2899] avg mini-batch loss:  1.204
# [epoch: 5, i:  2999] avg mini-batch loss:  1.445
# [epoch: 5, i:  3099] avg mini-batch loss:  1.297
# [epoch: 5, i:  3199] avg mini-batch loss:  1.187
# [epoch: 5, i:  3299] avg mini-batch loss:  1.121
# [epoch: 5, i:  3399] avg mini-batch loss:  1.754
# [epoch: 5, i:  3499] avg mini-batch loss:  1.159
# [epoch: 5, i:  3599] avg mini-batch loss:  1.256
# [epoch: 5, i:  3699] avg mini-batch loss:  1.114
# [epoch: 6, i:    99] avg mini-batch loss:  1.060
# [epoch: 6, i:   199] avg mini-batch loss:  1.412
# [epoch: 6, i:   299] avg mini-batch loss:  1.305
# [epoch: 6, i:   399] avg mini-batch loss:  1.166
# [epoch: 6, i:   499] avg mini-batch loss:  1.461
# [epoch: 6, i:   599] avg mini-batch loss:  1.494
# [epoch: 6, i:   699] avg mini-batch loss:  1.344
# [epoch: 6, i:   799] avg mini-batch loss:  1.296
# [epoch: 6, i:   899] avg mini-batch loss:  1.025
# [epoch: 6, i:   999] avg mini-batch loss:  1.524
# [epoch: 6, i:  1099] avg mini-batch loss:  1.140
# [epoch: 6, i:  1199] avg mini-batch loss:  1.318
# [epoch: 6, i:  1299] avg mini-batch loss:  1.153
# [epoch: 6, i:  1399] avg mini-batch loss:  1.072
# [epoch: 6, i:  1499] avg mini-batch loss:  1.276
# [epoch: 6, i:  1599] avg mini-batch loss:  1.219
# [epoch: 6, i:  1699] avg mini-batch loss:  1.470
# [epoch: 6, i:  1799] avg mini-batch loss:  1.279
# [epoch: 6, i:  1899] avg mini-batch loss:  1.394
# [epoch: 6, i:  1999] avg mini-batch loss:  1.151
# [epoch: 6, i:  2099] avg mini-batch loss:  1.408
# [epoch: 6, i:  2199] avg mini-batch loss:  1.423
# [epoch: 6, i:  2299] avg mini-batch loss:  1.201
# [epoch: 6, i:  2399] avg mini-batch loss:  1.199
# [epoch: 6, i:  2499] avg mini-batch loss:  1.526
# [epoch: 6, i:  2599] avg mini-batch loss:  0.998
# [epoch: 6, i:  2699] avg mini-batch loss:  1.441
# [epoch: 6, i:  2799] avg mini-batch loss:  1.220
# [epoch: 6, i:  2899] avg mini-batch loss:  1.578
# [epoch: 6, i:  2999] avg mini-batch loss:  1.625
# [epoch: 6, i:  3099] avg mini-batch loss:  1.053
# [epoch: 6, i:  3199] avg mini-batch loss:  1.250
# [epoch: 6, i:  3299] avg mini-batch loss:  1.227
# [epoch: 6, i:  3399] avg mini-batch loss:  0.984
# [epoch: 6, i:  3499] avg mini-batch loss:  1.304
# [epoch: 6, i:  3599] avg mini-batch loss:  1.562
# [epoch: 6, i:  3699] avg mini-batch loss:  1.436
# [epoch: 7, i:    99] avg mini-batch loss:  1.258
# [epoch: 7, i:   199] avg mini-batch loss:  1.355
# [epoch: 7, i:   299] avg mini-batch loss:  1.357
# [epoch: 7, i:   399] avg mini-batch loss:  0.921
# [epoch: 7, i:   499] avg mini-batch loss:  1.181
# [epoch: 7, i:   599] avg mini-batch loss:  1.398
# [epoch: 7, i:   699] avg mini-batch loss:  1.271
# [epoch: 7, i:   799] avg mini-batch loss:  1.625
# [epoch: 7, i:   899] avg mini-batch loss:  1.083
# [epoch: 7, i:   999] avg mini-batch loss:  1.294
# [epoch: 7, i:  1099] avg mini-batch loss:  1.634
# [epoch: 7, i:  1199] avg mini-batch loss:  1.378
# [epoch: 7, i:  1299] avg mini-batch loss:  1.547
# [epoch: 7, i:  1399] avg mini-batch loss:  1.444
# [epoch: 7, i:  1499] avg mini-batch loss:  1.092
# [epoch: 7, i:  1599] avg mini-batch loss:  0.931
# [epoch: 7, i:  1699] avg mini-batch loss:  1.159
# [epoch: 7, i:  1799] avg mini-batch loss:  1.407
# [epoch: 7, i:  1899] avg mini-batch loss:  1.166
# [epoch: 7, i:  1999] avg mini-batch loss:  1.274
# [epoch: 7, i:  2099] avg mini-batch loss:  1.089
# [epoch: 7, i:  2199] avg mini-batch loss:  1.161
# [epoch: 7, i:  2299] avg mini-batch loss:  0.975
# [epoch: 7, i:  2399] avg mini-batch loss:  1.809
# [epoch: 7, i:  2499] avg mini-batch loss:  1.133
# [epoch: 7, i:  2599] avg mini-batch loss:  1.260
# [epoch: 7, i:  2699] avg mini-batch loss:  1.296
# [epoch: 7, i:  2799] avg mini-batch loss:  1.413
# [epoch: 7, i:  2899] avg mini-batch loss:  1.241
# [epoch: 7, i:  2999] avg mini-batch loss:  1.237
# [epoch: 7, i:  3099] avg mini-batch loss:  1.328
# [epoch: 7, i:  3199] avg mini-batch loss:  1.548
# [epoch: 7, i:  3299] avg mini-batch loss:  1.410
# [epoch: 7, i:  3399] avg mini-batch loss:  1.276
# [epoch: 7, i:  3499] avg mini-batch loss:  1.157
# [epoch: 7, i:  3599] avg mini-batch loss:  1.109
# [epoch: 7, i:  3699] avg mini-batch loss:  1.278
# [epoch: 8, i:    99] avg mini-batch loss:  0.995
# [epoch: 8, i:   199] avg mini-batch loss:  1.101
# [epoch: 8, i:   299] avg mini-batch loss:  1.024
# [epoch: 8, i:   399] avg mini-batch loss:  1.229
# [epoch: 8, i:   499] avg mini-batch loss:  1.406
# [epoch: 8, i:   599] avg mini-batch loss:  1.399
# [epoch: 8, i:   699] avg mini-batch loss:  1.021
# [epoch: 8, i:   799] avg mini-batch loss:  1.140
# [epoch: 8, i:   899] avg mini-batch loss:  1.515
# [epoch: 8, i:   999] avg mini-batch loss:  1.194
# [epoch: 8, i:  1099] avg mini-batch loss:  1.258
# [epoch: 8, i:  1199] avg mini-batch loss:  1.151
# [epoch: 8, i:  1299] avg mini-batch loss:  1.061
# [epoch: 8, i:  1399] avg mini-batch loss:  1.377
# [epoch: 8, i:  1499] avg mini-batch loss:  1.383
# [epoch: 8, i:  1599] avg mini-batch loss:  1.487
# [epoch: 8, i:  1699] avg mini-batch loss:  1.710
# [epoch: 8, i:  1799] avg mini-batch loss:  1.380
# [epoch: 8, i:  1899] avg mini-batch loss:  1.323
# [epoch: 8, i:  1999] avg mini-batch loss:  1.164
# [epoch: 8, i:  2099] avg mini-batch loss:  1.334
# [epoch: 8, i:  2199] avg mini-batch loss:  1.314
# [epoch: 8, i:  2299] avg mini-batch loss:  1.438
# [epoch: 8, i:  2399] avg mini-batch loss:  1.059
# [epoch: 8, i:  2499] avg mini-batch loss:  1.343
# [epoch: 8, i:  2599] avg mini-batch loss:  1.560
# [epoch: 8, i:  2699] avg mini-batch loss:  1.244
# [epoch: 8, i:  2799] avg mini-batch loss:  1.262
# [epoch: 8, i:  2899] avg mini-batch loss:  1.499
# [epoch: 8, i:  2999] avg mini-batch loss:  1.041
# [epoch: 8, i:  3099] avg mini-batch loss:  1.384
# [epoch: 8, i:  3199] avg mini-batch loss:  1.840
# [epoch: 8, i:  3299] avg mini-batch loss:  1.297
# [epoch: 8, i:  3399] avg mini-batch loss:  0.947
# [epoch: 8, i:  3499] avg mini-batch loss:  1.117
# [epoch: 8, i:  3599] avg mini-batch loss:  1.287
# [epoch: 8, i:  3699] avg mini-batch loss:  1.513
# [epoch: 9, i:    99] avg mini-batch loss:  1.558
# [epoch: 9, i:   199] avg mini-batch loss:  1.008
# [epoch: 9, i:   299] avg mini-batch loss:  1.122
# [epoch: 9, i:   399] avg mini-batch loss:  1.194
# [epoch: 9, i:   499] avg mini-batch loss:  1.353
# [epoch: 9, i:   599] avg mini-batch loss:  1.500
# [epoch: 9, i:   699] avg mini-batch loss:  1.527
# [epoch: 9, i:   799] avg mini-batch loss:  1.215
# [epoch: 9, i:   899] avg mini-batch loss:  1.474
# [epoch: 9, i:   999] avg mini-batch loss:  1.253
# [epoch: 9, i:  1099] avg mini-batch loss:  1.227
# [epoch: 9, i:  1199] avg mini-batch loss:  1.566
# [epoch: 9, i:  1299] avg mini-batch loss:  1.287
# [epoch: 9, i:  1399] avg mini-batch loss:  1.587
# [epoch: 9, i:  1499] avg mini-batch loss:  1.298
# [epoch: 9, i:  1599] avg mini-batch loss:  1.222
# [epoch: 9, i:  1699] avg mini-batch loss:  1.139
# [epoch: 9, i:  1799] avg mini-batch loss:  1.601
# [epoch: 9, i:  1899] avg mini-batch loss:  1.660
# [epoch: 9, i:  1999] avg mini-batch loss:  1.344
# [epoch: 9, i:  2099] avg mini-batch loss:  1.069
# [epoch: 9, i:  2199] avg mini-batch loss:  1.413
# [epoch: 9, i:  2299] avg mini-batch loss:  1.194
# [epoch: 9, i:  2399] avg mini-batch loss:  1.204
# [epoch: 9, i:  2499] avg mini-batch loss:  1.618
# [epoch: 9, i:  2599] avg mini-batch loss:  1.038
# [epoch: 9, i:  2699] avg mini-batch loss:  1.340
# [epoch: 9, i:  2799] avg mini-batch loss:  1.435
# [epoch: 9, i:  2899] avg mini-batch loss:  1.137
# [epoch: 9, i:  2999] avg mini-batch loss:  1.107
# [epoch: 9, i:  3099] avg mini-batch loss:  1.442
# [epoch: 9, i:  3199] avg mini-batch loss:  1.650
# [epoch: 9, i:  3299] avg mini-batch loss:  1.172
# [epoch: 9, i:  3399] avg mini-batch loss:  1.350
# [epoch: 9, i:  3499] avg mini-batch loss:  1.251
# [epoch: 9, i:  3599] avg mini-batch loss:  1.364
# [epoch: 9, i:  3699] avg mini-batch loss:  1.222
# Finished Training.

# %%
# training loss curve
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# test the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for spectrograms, labels in test_loader:
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        outputs = model(spectrograms)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Accuracy: 50.0%
