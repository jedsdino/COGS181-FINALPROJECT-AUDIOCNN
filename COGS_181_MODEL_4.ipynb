# %% [markdown]
# # Convolutional Neural Networks for Audio Detection
# ## Setting Up

# %%
# copy from drive to working directory
# !cp -r /content/drive/MyDrive/COGS181_DATA /content/COGS181

# %%
# libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torchaudio
import os
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt

# %%
# audio (WAV) files
## train
train_real_path = "/content/COGS181/train_real"
train_fake_path = "/content/COGS181/train_fake"

## test
test_real_path  = "/content/COGS181/test_real"
test_fake_path  = "/content/COGS181/test_fake"

# %%
# get the files from the folder to use
def file_to_folder(folder, label):
  files = []
  labels = []
  for filename in os.listdir(folder):
    # Exclude macOS resource fork files that start with '._'
    if filename.lower().endswith(".wav") and not filename.startswith('._'):
      files.append(os.path.join(folder, filename))
      labels.append(label)
  return files, labels

# get files and labels
## train
train_real_files, train_real_labels = file_to_folder(train_real_path, 0)
train_fake_files, train_fake_labels = file_to_folder(train_fake_path, 1)


## test
test_real_files, test_real_labels = file_to_folder(test_real_path, 0)
test_fake_files, test_fake_labels = file_to_folder(test_fake_path, 1)

## combine for train, validation, and test datasets
train_files = train_real_files + train_fake_files
train_labels = train_real_labels + train_fake_labels

test_files = test_real_files + test_fake_files
test_labels = test_real_labels + test_fake_labels

len(train_files), len(test_files)
# Out:
# (3750, 1250)

# %%
# define audiodataset
class AudioDataset(Dataset):
    def __init__(self, audio_files, labels):
        self.audio_files = audio_files
        self.labels = labels
        self.transform = torchaudio.transforms.Spectrogram()

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        waveform, _ = torchaudio.load(self.audio_files[idx])
        spectrogram = self.transform(waveform)
        label = self.labels[idx]
        return spectrogram, label

# %%
# getting the train/test dataset and loader
train_dataset = AudioDataset(train_files, train_labels)
test_dataset = AudioDataset(test_files, test_labels)

train_loader = DataLoader(train_dataset, batch_size = 1, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = 1)

# %% [markdown]
# # Neural Network IV
# Total layers: 5
#
# Activation function: ReLU
#
# Pooling functions: max pooling, adaptive average pool
#
# Optimization: SGD
#
# Regularization: N/A
#
# Normalization: N/A

# %%
# audio CNN definition
class AudioCNN(nn.Module):
    def __init__(self):
        super(AudioCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size = 3)
        self.pool = nn.MaxPool2d(2)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(16 * 1 * 1, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.avg_pool(x)
        x = x.view(-1, 16 * 1 * 1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = AudioCNN()

# %%
# loss function and optimizer
# EDIT
loss_func = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.001)

# %%
# training the model
avg_losses = []
num_epochs = 10
print_freq = 100

for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (spectrograms, labels) in enumerate(train_loader, 0):
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        optimizer.zero_grad()
        outputs = model(spectrograms)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # not in original article but added for consistency
        if i % print_freq == print_freq - 1:
          avg_loss = running_loss / print_freq
          print("[epoch: {}, i: {:5d}] avg mini-batch loss: {: .3f}".format(epoch, i, avg_loss))
          avg_losses.append(avg_loss)
          running_loss = 0.0

print("Finished Training.")
# Out:
# [epoch: 0, i:    99] avg mini-batch loss:  0.703
# [epoch: 0, i:   199] avg mini-batch loss:  0.682
# [epoch: 0, i:   299] avg mini-batch loss:  0.642
# [epoch: 0, i:   399] avg mini-batch loss:  0.624
# [epoch: 0, i:   499] avg mini-batch loss:  0.633
# [epoch: 0, i:   599] avg mini-batch loss:  0.631
# [epoch: 0, i:   699] avg mini-batch loss:  0.593
# [epoch: 0, i:   799] avg mini-batch loss:  0.662
# [epoch: 0, i:   899] avg mini-batch loss:  0.636
# [epoch: 0, i:   999] avg mini-batch loss:  0.606
# [epoch: 0, i:  1099] avg mini-batch loss:  0.636
# [epoch: 0, i:  1199] avg mini-batch loss:  0.601
# [epoch: 0, i:  1299] avg mini-batch loss:  0.622
# [epoch: 0, i:  1399] avg mini-batch loss:  0.617
# [epoch: 0, i:  1499] avg mini-batch loss:  0.615
# [epoch: 0, i:  1599] avg mini-batch loss:  0.605
# [epoch: 0, i:  1699] avg mini-batch loss:  0.635
# [epoch: 0, i:  1799] avg mini-batch loss:  0.634
# [epoch: 0, i:  1899] avg mini-batch loss:  0.630
# [epoch: 0, i:  1999] avg mini-batch loss:  0.634
# [epoch: 0, i:  2099] avg mini-batch loss:  0.639
# [epoch: 0, i:  2199] avg mini-batch loss:  0.606
# [epoch: 0, i:  2299] avg mini-batch loss:  0.601
# [epoch: 0, i:  2399] avg mini-batch loss:  0.575
# [epoch: 0, i:  2499] avg mini-batch loss:  0.669
# [epoch: 0, i:  2599] avg mini-batch loss:  0.570
# [epoch: 0, i:  2699] avg mini-batch loss:  0.558
# [epoch: 0, i:  2799] avg mini-batch loss:  0.589
# [epoch: 0, i:  2899] avg mini-batch loss:  0.609
# [epoch: 0, i:  2999] avg mini-batch loss:  0.654
# [epoch: 0, i:  3099] avg mini-batch loss:  0.578
# [epoch: 0, i:  3199] avg mini-batch loss:  0.624
# [epoch: 0, i:  3299] avg mini-batch loss:  0.633
# [epoch: 0, i:  3399] avg mini-batch loss:  0.621
# [epoch: 0, i:  3499] avg mini-batch loss:  0.562
# [epoch: 0, i:  3599] avg mini-batch loss:  0.548
# [epoch: 0, i:  3699] avg mini-batch loss:  0.568
# [epoch: 1, i:    99] avg mini-batch loss:  0.589
# [epoch: 1, i:   199] avg mini-batch loss:  0.627
# [epoch: 1, i:   299] avg mini-batch loss:  0.566
# [epoch: 1, i:   399] avg mini-batch loss:  0.596
# [epoch: 1, i:   499] avg mini-batch loss:  0.595
# [epoch: 1, i:   599] avg mini-batch loss:  0.630
# [epoch: 1, i:   699] avg mini-batch loss:  0.626
# [epoch: 1, i:   799] avg mini-batch loss:  0.611
# [epoch: 1, i:   899] avg mini-batch loss:  0.550
# [epoch: 1, i:   999] avg mini-batch loss:  0.588
# [epoch: 1, i:  1099] avg mini-batch loss:  0.617
# [epoch: 1, i:  1199] avg mini-batch loss:  0.536
# [epoch: 1, i:  1299] avg mini-batch loss:  0.646
# [epoch: 1, i:  1399] avg mini-batch loss:  0.544
# [epoch: 1, i:  1499] avg mini-batch loss:  0.594
# [epoch: 1, i:  1599] avg mini-batch loss:  0.580
# [epoch: 1, i:  1699] avg mini-batch loss:  0.618
# [epoch: 1, i:  1799] avg mini-batch loss:  0.604
# [epoch: 1, i:  1899] avg mini-batch loss:  0.643
# [epoch: 1, i:  1999] avg mini-batch loss:  0.623
# [epoch: 1, i:  2099] avg mini-batch loss:  0.576
# [epoch: 1, i:  2199] avg mini-batch loss:  0.602
# [epoch: 1, i:  2299] avg mini-batch loss:  0.556
# [epoch: 1, i:  2399] avg mini-batch loss:  0.612
# [epoch: 1, i:  2499] avg mini-batch loss:  0.555
# [epoch: 1, i:  2599] avg mini-batch loss:  0.580
# [epoch: 1, i:  2699] avg mini-batch loss:  0.549
# [epoch: 1, i:  2799] avg mini-batch loss:  0.586
# [epoch: 1, i:  2899] avg mini-batch loss:  0.549
# [epoch: 1, i:  2999] avg mini-batch loss:  0.627
# [epoch: 1, i:  3099] avg mini-batch loss:  0.584
# [epoch: 1, i:  3199] avg mini-batch loss:  0.630
# [epoch: 1, i:  3299] avg mini-batch loss:  0.576
# [epoch: 1, i:  3399] avg mini-batch loss:  0.599
# [epoch: 1, i:  3499] avg mini-batch loss:  0.581
# [epoch: 1, i:  3599] avg mini-batch loss:  0.623
# [epoch: 1, i:  3699] avg mini-batch loss:  0.536
# [epoch: 2, i:    99] avg mini-batch loss:  0.628
# [epoch: 2, i:   199] avg mini-batch loss:  0.579
# [epoch: 2, i:   299] avg mini-batch loss:  0.581
# [epoch: 2, i:   399] avg mini-batch loss:  0.558
# [epoch: 2, i:   499] avg mini-batch loss:  0.614
# [epoch: 2, i:   599] avg mini-batch loss:  0.625
# [epoch: 2, i:   699] avg mini-batch loss:  0.596
# [epoch: 2, i:   799] avg mini-batch loss:  0.598
# [epoch: 2, i:   899] avg mini-batch loss:  0.622
# [epoch: 2, i:   999] avg mini-batch loss:  0.577
# [epoch: 2, i:  1099] avg mini-batch loss:  0.589
# [epoch: 2, i:  1199] avg mini-batch loss:  0.592
# [epoch: 2, i:  1299] avg mini-batch loss:  0.549
# [epoch: 2, i:  1399] avg mini-batch loss:  0.581
# [epoch: 2, i:  1499] avg mini-batch loss:  0.584
# [epoch: 2, i:  1599] avg mini-batch loss:  0.637
# [epoch: 2, i:  1699] avg mini-batch loss:  0.592
# [epoch: 2, i:  1799] avg mini-batch loss:  0.519
# [epoch: 2, i:  1899] avg mini-batch loss:  0.629
# [epoch: 2, i:  1999] avg mini-batch loss:  0.568
# [epoch: 2, i:  2099] avg mini-batch loss:  0.594
# [epoch: 2, i:  2199] avg mini-batch loss:  0.599
# [epoch: 2, i:  2299] avg mini-batch loss:  0.582
# [epoch: 2, i:  2399] avg mini-batch loss:  0.590
# [epoch: 2, i:  2499] avg mini-batch loss:  0.586
# [epoch: 2, i:  2599] avg mini-batch loss:  0.585
# [epoch: 2, i:  2699] avg mini-batch loss:  0.568
# [epoch: 2, i:  2799] avg mini-batch loss:  0.637
# [epoch: 2, i:  2899] avg mini-batch loss:  0.577
# [epoch: 2, i:  2999] avg mini-batch loss:  0.588
# [epoch: 2, i:  3099] avg mini-batch loss:  0.585
# [epoch: 2, i:  3199] avg mini-batch loss:  0.602
# [epoch: 2, i:  3299] avg mini-batch loss:  0.560
# [epoch: 2, i:  3399] avg mini-batch loss:  0.558
# [epoch: 2, i:  3499] avg mini-batch loss:  0.570
# [epoch: 2, i:  3599] avg mini-batch loss:  0.565
# [epoch: 2, i:  3699] avg mini-batch loss:  0.598
# [epoch: 3, i:    99] avg mini-batch loss:  0.536
# [epoch: 3, i:   199] avg mini-batch loss:  0.611
# [epoch: 3, i:   299] avg mini-batch loss:  0.601
# [epoch: 3, i:   399] avg mini-batch loss:  0.560
# [epoch: 3, i:   499] avg mini-batch loss:  0.554
# [epoch: 3, i:   599] avg mini-batch loss:  0.610
# [epoch: 3, i:   699] avg mini-batch loss:  0.561
# [epoch: 3, i:   799] avg mini-batch loss:  0.580
# [epoch: 3, i:   899] avg mini-batch loss:  0.592
# [epoch: 3, i:   999] avg mini-batch loss:  0.552
# [epoch: 3, i:  1099] avg mini-batch loss:  0.587
# [epoch: 3, i:  1199] avg mini-batch loss:  0.547
# [epoch: 3, i:  1299] avg mini-batch loss:  0.589
# [epoch: 3, i:  1399] avg mini-batch loss:  0.599
# [epoch: 3, i:  1499] avg mini-batch loss:  0.586
# [epoch: 3, i:  1599] avg mini-batch loss:  0.601
# [epoch: 3, i:  1699] avg mini-batch loss:  0.616
# [epoch: 3, i:  1799] avg mini-batch loss:  0.567
# [epoch: 3, i:  1899] avg mini-batch loss:  0.511
# [epoch: 3, i:  1999] avg mini-batch loss:  0.539
# [epoch: 3, i:  2099] avg mini-batch loss:  0.570
# [epoch: 3, i:  2199] avg mini-batch loss:  0.589
# [epoch: 3, i:  2299] avg mini-batch loss:  0.672
# [epoch: 3, i:  2399] avg mini-batch loss:  0.557
# [epoch: 3, i:  2499] avg mini-batch loss:  0.588
# [epoch: 3, i:  2599] avg mini-batch loss:  0.625
# [epoch: 3, i:  2699] avg mini-batch loss:  0.648
# [epoch: 3, i:  2799] avg mini-batch loss:  0.577
# [epoch: 3, i:  2899] avg mini-batch loss:  0.575
# [epoch: 3, i:  2999] avg mini-batch loss:  0.572
# [epoch: 3, i:  3099] avg mini-batch loss:  0.547
# [epoch: 3, i:  3199] avg mini-batch loss:  0.618
# [epoch: 3, i:  3299] avg mini-batch loss:  0.569
# [epoch: 3, i:  3399] avg mini-batch loss:  0.499
# [epoch: 3, i:  3499] avg mini-batch loss:  0.584
# [epoch: 3, i:  3599] avg mini-batch loss:  0.608
# [epoch: 3, i:  3699] avg mini-batch loss:  0.651
# [epoch: 4, i:    99] avg mini-batch loss:  0.571
# [epoch: 4, i:   199] avg mini-batch loss:  0.620
# [epoch: 4, i:   299] avg mini-batch loss:  0.597
# [epoch: 4, i:   399] avg mini-batch loss:  0.557
# [epoch: 4, i:   499] avg mini-batch loss:  0.597
# [epoch: 4, i:   599] avg mini-batch loss:  0.573
# [epoch: 4, i:   699] avg mini-batch loss:  0.596
# [epoch: 4, i:   799] avg mini-batch loss:  0.643
# [epoch: 4, i:   899] avg mini-batch loss:  0.606
# [epoch: 4, i:   999] avg mini-batch loss:  0.578
# [epoch: 4, i:  1099] avg mini-batch loss:  0.599
# [epoch: 4, i:  1199] avg mini-batch loss:  0.569
# [epoch: 4, i:  1299] avg mini-batch loss:  0.556
# [epoch: 4, i:  1399] avg mini-batch loss:  0.538
# [epoch: 4, i:  1499] avg mini-batch loss:  0.621
# [epoch: 4, i:  1599] avg mini-batch loss:  0.586
# [epoch: 4, i:  1699] avg mini-batch loss:  0.502
# [epoch: 4, i:  1799] avg mini-batch loss:  0.531
# [epoch: 4, i:  1899] avg mini-batch loss:  0.555
# [epoch: 4, i:  1999] avg mini-batch loss:  0.621
# [epoch: 4, i:  2099] avg mini-batch loss:  0.562
# [epoch: 4, i:  2199] avg mini-batch loss:  0.571
# [epoch: 4, i:  2299] avg mini-batch loss:  0.548
# [epoch: 4, i:  2399] avg mini-batch loss:  0.594
# [epoch: 4, i:  2499] avg mini-batch loss:  0.612
# [epoch: 4, i:  2599] avg mini-batch loss:  0.581
# [epoch: 4, i:  2699] avg mini-batch loss:  0.572
# [epoch: 4, i:  2799] avg mini-batch loss:  0.560
# [epoch: 4, i:  2899] avg mini-batch loss:  0.580
# [epoch: 4, i:  2999] avg mini-batch loss:  0.593
# [epoch: 4, i:  3099] avg mini-batch loss:  0.564
# [epoch: 4, i:  3199] avg mini-batch loss:  0.570
# [epoch: 4, i:  3299] avg mini-batch loss:  0.566
# [epoch: 4, i:  3399] avg mini-batch loss:  0.522
# [epoch: 4, i:  3499] avg mini-batch loss:  0.623
# [epoch: 4, i:  3599] avg mini-batch loss:  0.558
# [epoch: 4, i:  3699] avg mini-batch loss:  0.569
# [epoch: 5, i:    99] avg mini-batch loss:  0.635
# [epoch: 5, i:   199] avg mini-batch loss:  0.594
# [epoch: 5, i:   299] avg mini-batch loss:  0.577
# [epoch: 5, i:   399] avg mini-batch loss:  0.576
# [epoch: 5, i:   499] avg mini-batch loss:  0.576
# [epoch: 5, i:   599] avg mini-batch loss:  0.571
# [epoch: 5, i:   699] avg mini-batch loss:  0.574
# [epoch: 5, i:   799] avg mini-batch loss:  0.574
# [epoch: 5, i:   899] avg mini-batch loss:  0.546
# [epoch: 5, i:   999] avg mini-batch loss:  0.566
# [epoch: 5, i:  1099] avg mini-batch loss:  0.518
# [epoch: 5, i:  1199] avg mini-batch loss:  0.609
# [epoch: 5, i:  1299] avg mini-batch loss:  0.551
# [epoch: 5, i:  1399] avg mini-batch loss:  0.583
# [epoch: 5, i:  1499] avg mini-batch loss:  0.595
# [epoch: 5, i:  1599] avg mini-batch loss:  0.578
# [epoch: 5, i:  1699] avg mini-batch loss:  0.615
# [epoch: 5, i:  1799] avg mini-batch loss:  0.584
# [epoch: 5, i:  1899] avg mini-batch loss:  0.598
# [epoch: 5, i:  1999] avg mini-batch loss:  0.632
# [epoch: 5, i:  2099] avg mini-batch loss:  0.575
# [epoch: 5, i:  2199] avg mini-batch loss:  0.610
# [epoch: 5, i:  2299] avg mini-batch loss:  0.516
# [epoch: 5, i:  2399] avg mini-batch loss:  0.551
# [epoch: 5, i:  2499] avg mini-batch loss:  0.530
# [epoch: 5, i:  2599] avg mini-batch loss:  0.601
# [epoch: 5, i:  2699] avg mini-batch loss:  0.557
# [epoch: 5, i:  2799] avg mini-batch loss:  0.506
# [epoch: 5, i:  2899] avg mini-batch loss:  0.584
# [epoch: 5, i:  2999] avg mini-batch loss:  0.508
# [epoch: 5, i:  3099] avg mini-batch loss:  0.603
# [epoch: 5, i:  3199] avg mini-batch loss:  0.546
# [epoch: 5, i:  3299] avg mini-batch loss:  0.589
# [epoch: 5, i:  3399] avg mini-batch loss:  0.593
# [epoch: 5, i:  3499] avg mini-batch loss:  0.569
# [epoch: 5, i:  3599] avg mini-batch loss:  0.579
# [epoch: 5, i:  3699] avg mini-batch loss:  0.563
# [epoch: 6, i:    99] avg mini-batch loss:  0.569
# [epoch: 6, i:   199] avg mini-batch loss:  0.531
# [epoch: 6, i:   299] avg mini-batch loss:  0.589
# [epoch: 6, i:   399] avg mini-batch loss:  0.618
# [epoch: 6, i:   499] avg mini-batch loss:  0.619
# [epoch: 6, i:   599] avg mini-batch loss:  0.553
# [epoch: 6, i:   699] avg mini-batch loss:  0.516
# [epoch: 6, i:   799] avg mini-batch loss:  0.558
# [epoch: 6, i:   899] avg mini-batch loss:  0.643
# [epoch: 6, i:   999] avg mini-batch loss:  0.510
# [epoch: 6, i:  1099] avg mini-batch loss:  0.616
# [epoch: 6, i:  1199] avg mini-batch loss:  0.587
# [epoch: 6, i:  1299] avg mini-batch loss:  0.572
# [epoch: 6, i:  1399] avg mini-batch loss:  0.589
# [epoch: 6, i:  1499] avg mini-batch loss:  0.490
# [epoch: 6, i:  1599] avg mini-batch loss:  0.606
# [epoch: 6, i:  1699] avg mini-batch loss:  0.535
# [epoch: 6, i:  1799] avg mini-batch loss:  0.579
# [epoch: 6, i:  1899] avg mini-batch loss:  0.548
# [epoch: 6, i:  1999] avg mini-batch loss:  0.558
# [epoch: 6, i:  2099] avg mini-batch loss:  0.634
# [epoch: 6, i:  2199] avg mini-batch loss:  0.576
# [epoch: 6, i:  2299] avg mini-batch loss:  0.548
# [epoch: 6, i:  2399] avg mini-batch loss:  0.599
# [epoch: 6, i:  2499] avg mini-batch loss:  0.539
# [epoch: 6, i:  2599] avg mini-batch loss:  0.544
# [epoch: 6, i:  2699] avg mini-batch loss:  0.499
# [epoch: 6, i:  2799] avg mini-batch loss:  0.537
# [epoch: 6, i:  2899] avg mini-batch loss:  0.591
# [epoch: 6, i:  2999] avg mini-batch loss:  0.553
# [epoch: 6, i:  3099] avg mini-batch loss:  0.583
# [epoch: 6, i:  3199] avg mini-batch loss:  0.602
# [epoch: 6, i:  3299] avg mini-batch loss:  0.548
# [epoch: 6, i:  3399] avg mini-batch loss:  0.560
# [epoch: 6, i:  3499] avg mini-batch loss:  0.597
# [epoch: 6, i:  3599] avg mini-batch loss:  0.590
# [epoch: 6, i:  3699] avg mini-batch loss:  0.550
# [epoch: 7, i:    99] avg mini-batch loss:  0.546
# [epoch: 7, i:   199] avg mini-batch loss:  0.577
# [epoch: 7, i:   299] avg mini-batch loss:  0.634
# [epoch: 7, i:   399] avg mini-batch loss:  0.575
# [epoch: 7, i:   499] avg mini-batch loss:  0.581
# [epoch: 7, i:   599] avg mini-batch loss:  0.577
# [epoch: 7, i:   699] avg mini-batch loss:  0.556
# [epoch: 7, i:   799] avg mini-batch loss:  0.520
# [epoch: 7, i:   899] avg mini-batch loss:  0.596
# [epoch: 7, i:   999] avg mini-batch loss:  0.535
# [epoch: 7, i:  1099] avg mini-batch loss:  0.551
# [epoch: 7, i:  1199] avg mini-batch loss:  0.533
# [epoch: 7, i:  1299] avg mini-batch loss:  0.589
# [epoch: 7, i:  1399] avg mini-batch loss:  0.562
# [epoch: 7, i:  1499] avg mini-batch loss:  0.556
# [epoch: 7, i:  1599] avg mini-batch loss:  0.520
# [epoch: 7, i:  1699] avg mini-batch loss:  0.541
# [epoch: 7, i:  1799] avg mini-batch loss:  0.591
# [epoch: 7, i:  1899] avg mini-batch loss:  0.586
# [epoch: 7, i:  1999] avg mini-batch loss:  0.568
# [epoch: 7, i:  2099] avg mini-batch loss:  0.565
# [epoch: 7, i:  2199] avg mini-batch loss:  0.583
# [epoch: 7, i:  2299] avg mini-batch loss:  0.555
# [epoch: 7, i:  2399] avg mini-batch loss:  0.544
# [epoch: 7, i:  2499] avg mini-batch loss:  0.589
# [epoch: 7, i:  2599] avg mini-batch loss:  0.585
# [epoch: 7, i:  2699] avg mini-batch loss:  0.538
# [epoch: 7, i:  2799] avg mini-batch loss:  0.571
# [epoch: 7, i:  2899] avg mini-batch loss:  0.573
# [epoch: 7, i:  2999] avg mini-batch loss:  0.508
# [epoch: 7, i:  3099] avg mini-batch loss:  0.569
# [epoch: 7, i:  3199] avg mini-batch loss:  0.586
# [epoch: 7, i:  3299] avg mini-batch loss:  0.599
# [epoch: 7, i:  3399] avg mini-batch loss:  0.549
# [epoch: 7, i:  3499] avg mini-batch loss:  0.597
# [epoch: 7, i:  3599] avg mini-batch loss:  0.599
# [epoch: 7, i:  3699] avg mini-batch loss:  0.527
# [epoch: 8, i:    99] avg mini-batch loss:  0.597
# [epoch: 8, i:   199] avg mini-batch loss:  0.541
# [epoch: 8, i:   299] avg mini-batch loss:  0.515
# [epoch: 8, i:   399] avg mini-batch loss:  0.574
# [epoch: 8, i:   499] avg mini-batch loss:  0.540
# [epoch: 8, i:   599] avg mini-batch loss:  0.552
# [epoch: 8, i:   699] avg mini-batch loss:  0.587
# [epoch: 8, i:   799] avg mini-batch loss:  0.512
# [epoch: 8, i:   899] avg mini-batch loss:  0.570
# [epoch: 8, i:   999] avg mini-batch loss:  0.533
# [epoch: 8, i:  1099] avg mini-batch loss:  0.581
# [epoch: 8, i:  1199] avg mini-batch loss:  0.566
# [epoch: 8, i:  1299] avg mini-batch loss:  0.606
# [epoch: 8, i:  1399] avg mini-batch loss:  0.534
# [epoch: 8, i:  1499] avg mini-batch loss:  0.603
# [epoch: 8, i:  1599] avg mini-batch loss:  0.494
# [epoch: 8, i:  1699] avg mini-batch loss:  0.599
# [epoch: 8, i:  1799] avg mini-batch loss:  0.479
# [epoch: 8, i:  1899] avg mini-batch loss:  0.532
# [epoch: 8, i:  1999] avg mini-batch loss:  0.552
# [epoch: 8, i:  2099] avg mini-batch loss:  0.569
# [epoch: 8, i:  2199] avg mini-batch loss:  0.566
# [epoch: 8, i:  2299] avg mini-batch loss:  0.589
# [epoch: 8, i:  2399] avg mini-batch loss:  0.550
# [epoch: 8, i:  2499] avg mini-batch loss:  0.541
# [epoch: 8, i:  2599] avg mini-batch loss:  0.558
# [epoch: 8, i:  2699] avg mini-batch loss:  0.541
# [epoch: 8, i:  2799] avg mini-batch loss:  0.585
# [epoch: 8, i:  2899] avg mini-batch loss:  0.613
# [epoch: 8, i:  2999] avg mini-batch loss:  0.551
# [epoch: 8, i:  3099] avg mini-batch loss:  0.533
# [epoch: 8, i:  3199] avg mini-batch loss:  0.557
# [epoch: 8, i:  3299] avg mini-batch loss:  0.539
# [epoch: 8, i:  3399] avg mini-batch loss:  0.559
# [epoch: 8, i:  3499] avg mini-batch loss:  0.568
# [epoch: 8, i:  3599] avg mini-batch loss:  0.646
# [epoch: 8, i:  3699] avg mini-batch loss:  0.538
# [epoch: 9, i:    99] avg mini-batch loss:  0.546
# [epoch: 9, i:   199] avg mini-batch loss:  0.536
# [epoch: 9, i:   299] avg mini-batch loss:  0.559
# [epoch: 9, i:   399] avg mini-batch loss:  0.560
# [epoch: 9, i:   499] avg mini-batch loss:  0.527
# [epoch: 9, i:   599] avg mini-batch loss:  0.509
# [epoch: 9, i:   699] avg mini-batch loss:  0.586
# [epoch: 9, i:   799] avg mini-batch loss:  0.549
# [epoch: 9, i:   899] avg mini-batch loss:  0.543
# [epoch: 9, i:   999] avg mini-batch loss:  0.569
# [epoch: 9, i:  1099] avg mini-batch loss:  0.565
# [epoch: 9, i:  1199] avg mini-batch loss:  0.548
# [epoch: 9, i:  1299] avg mini-batch loss:  0.546
# [epoch: 9, i:  1399] avg mini-batch loss:  0.583
# [epoch: 9, i:  1499] avg mini-batch loss:  0.587
# [epoch: 9, i:  1599] avg mini-batch loss:  0.494
# [epoch: 9, i:  1699] avg mini-batch loss:  0.584
# [epoch: 9, i:  1799] avg mini-batch loss:  0.590
# [epoch: 9, i:  1899] avg mini-batch loss:  0.553
# [epoch: 9, i:  1999] avg mini-batch loss:  0.571
# [epoch: 9, i:  2099] avg mini-batch loss:  0.575
# [epoch: 9, i:  2199] avg mini-batch loss:  0.549
# [epoch: 9, i:  2299] avg mini-batch loss:  0.574
# [epoch: 9, i:  2399] avg mini-batch loss:  0.587
# [epoch: 9, i:  2499] avg mini-batch loss:  0.523
# [epoch: 9, i:  2599] avg mini-batch loss:  0.537
# [epoch: 9, i:  2699] avg mini-batch loss:  0.537
# [epoch: 9, i:  2799] avg mini-batch loss:  0.615
# [epoch: 9, i:  2899] avg mini-batch loss:  0.621
# [epoch: 9, i:  2999] avg mini-batch loss:  0.502
# [epoch: 9, i:  3099] avg mini-batch loss:  0.580
# [epoch: 9, i:  3199] avg mini-batch loss:  0.534
# [epoch: 9, i:  3299] avg mini-batch loss:  0.597
# [epoch: 9, i:  3399] avg mini-batch loss:  0.556
# [epoch: 9, i:  3499] avg mini-batch loss:  0.538
# [epoch: 9, i:  3599] avg mini-batch loss:  0.463
# [epoch: 9, i:  3699] avg mini-batch loss:  0.504
# Finished Training.

# %%
# training loss curve
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# test the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for spectrograms, labels in test_loader:
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        outputs = model(spectrograms)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Accuracy: 48.64%
