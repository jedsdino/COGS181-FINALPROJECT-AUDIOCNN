# %% [markdown]
# #Convolutional Neural Networks for Audio Detection
# ## Setting Up

# %%
# copy from drive to working directory
# !cp -r /content/drive/MyDrive/COGS181_DATA /content/COGS181

# %%
# libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torchaudio
import os
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt

# %%
# audio (WAV) files
## train
train_real_path = "/content/COGS181/train_real"
train_fake_path = "/content/COGS181/train_fake"

## test
test_real_path  = "/content/COGS181/test_real"
test_fake_path  = "/content/COGS181/test_fake"

# %%
# get the files from the folder to use
def file_to_folder(folder, label):
  files = []
  labels = []
  for filename in os.listdir(folder):
    # Exclude macOS resource fork files that start with '._'
    if filename.lower().endswith(".wav") and not filename.startswith('._'):
      files.append(os.path.join(folder, filename))
      labels.append(label)
  return files, labels

# get files and labels
## train
train_real_files, train_real_labels = file_to_folder(train_real_path, 0)
train_fake_files, train_fake_labels = file_to_folder(train_fake_path, 1)


## test
test_real_files, test_real_labels = file_to_folder(test_real_path, 0)
test_fake_files, test_fake_labels = file_to_folder(test_fake_path, 1)

## combine for train, validation, and test datasets
train_files = train_real_files + train_fake_files
train_labels = train_real_labels + train_fake_labels

test_files = test_real_files + test_fake_files
test_labels = test_real_labels + test_fake_labels

len(train_files), len(test_files)
# Out:
# (3750, 1250)

# %%
# define audiodataset
class AudioDataset(Dataset):
    def __init__(self, audio_files, labels):
        self.audio_files = audio_files
        self.labels = labels
        self.transform = torchaudio.transforms.Spectrogram()

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        waveform, _ = torchaudio.load(self.audio_files[idx])
        spectrogram = self.transform(waveform)
        label = self.labels[idx]
        return spectrogram, label

# %%
# getting the train/test dataset and loader
train_dataset = AudioDataset(train_files, train_labels)
test_dataset = AudioDataset(test_files, test_labels)

train_loader = DataLoader(train_dataset, batch_size = 1, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = 1)

# %% [markdown]
# # Neural Network III
# Total layers: 6
#
# Activation function: sigmoid
#
# Pooling functions: average pooling and adaptive average pooling
#
# Optimization: SGD
#
# Regularization: N/A
#
# Normalization: N/A

# %%
# audio CNN definition
class AudioCNN(nn.Module):
    def __init__(self):
        super(AudioCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size = 3)
        self.pool = nn.AvgPool2d(2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size = 3)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(32 * 1 * 1, 128)
        self.fc2 = nn.Linear(128, 2)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.pool(self.sigmoid(self.conv1(x)))
        x = self.pool(self.sigmoid(self.conv2(x)))
        x = self.avg_pool(x)
        x = x.view(-1, 32 * 1 * 1)
        x = self.sigmoid(self.fc1(x))
        x = self.fc2(x)

        return x

model = AudioCNN()

# %%
# loss function and optimizer
# EDIT
loss_func = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.001)

# %%
# training the model
avg_losses = []
num_epochs = 10
print_freq = 100

for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (spectrograms, labels) in enumerate(train_loader, 0):
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        optimizer.zero_grad()
        outputs = model(spectrograms)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # not in original article but added for consistency
        if i % print_freq == print_freq - 1:
          avg_loss = running_loss / print_freq
          print("[epoch: {}, i: {:5d}] avg mini-batch loss: {: .3f}".format(epoch, i, avg_loss))
          avg_losses.append(avg_loss)
          running_loss = 0.0

print("Finished Training.")
# Out:
# [epoch: 0, i:    99] avg mini-batch loss:  0.705
# [epoch: 0, i:   199] avg mini-batch loss:  0.694
# [epoch: 0, i:   299] avg mini-batch loss:  0.704
# [epoch: 0, i:   399] avg mini-batch loss:  0.700
# [epoch: 0, i:   499] avg mini-batch loss:  0.682
# [epoch: 0, i:   599] avg mini-batch loss:  0.703
# [epoch: 0, i:   699] avg mini-batch loss:  0.700
# [epoch: 0, i:   799] avg mini-batch loss:  0.693
# [epoch: 0, i:   899] avg mini-batch loss:  0.697
# [epoch: 0, i:   999] avg mini-batch loss:  0.696
# [epoch: 0, i:  1099] avg mini-batch loss:  0.702
# [epoch: 0, i:  1199] avg mini-batch loss:  0.699
# [epoch: 0, i:  1299] avg mini-batch loss:  0.700
# [epoch: 0, i:  1399] avg mini-batch loss:  0.698
# [epoch: 0, i:  1499] avg mini-batch loss:  0.698
# [epoch: 0, i:  1599] avg mini-batch loss:  0.698
# [epoch: 0, i:  1699] avg mini-batch loss:  0.700
# [epoch: 0, i:  1799] avg mini-batch loss:  0.698
# [epoch: 0, i:  1899] avg mini-batch loss:  0.702
# [epoch: 0, i:  1999] avg mini-batch loss:  0.692
# [epoch: 0, i:  2099] avg mini-batch loss:  0.699
# [epoch: 0, i:  2199] avg mini-batch loss:  0.699
# [epoch: 0, i:  2299] avg mini-batch loss:  0.691
# [epoch: 0, i:  2399] avg mini-batch loss:  0.689
# [epoch: 0, i:  2499] avg mini-batch loss:  0.702
# [epoch: 0, i:  2599] avg mini-batch loss:  0.683
# [epoch: 0, i:  2699] avg mini-batch loss:  0.703
# [epoch: 0, i:  2799] avg mini-batch loss:  0.701
# [epoch: 0, i:  2899] avg mini-batch loss:  0.700
# [epoch: 0, i:  2999] avg mini-batch loss:  0.701
# [epoch: 0, i:  3099] avg mini-batch loss:  0.698
# [epoch: 0, i:  3199] avg mini-batch loss:  0.700
# [epoch: 0, i:  3299] avg mini-batch loss:  0.700
# [epoch: 0, i:  3399] avg mini-batch loss:  0.697
# [epoch: 0, i:  3499] avg mini-batch loss:  0.691
# [epoch: 0, i:  3599] avg mini-batch loss:  0.702
# [epoch: 0, i:  3699] avg mini-batch loss:  0.701
# [epoch: 1, i:    99] avg mini-batch loss:  0.697
# [epoch: 1, i:   199] avg mini-batch loss:  0.698
# [epoch: 1, i:   299] avg mini-batch loss:  0.695
# [epoch: 1, i:   399] avg mini-batch loss:  0.700
# [epoch: 1, i:   499] avg mini-batch loss:  0.700
# [epoch: 1, i:   599] avg mini-batch loss:  0.699
# [epoch: 1, i:   699] avg mini-batch loss:  0.689
# [epoch: 1, i:   799] avg mini-batch loss:  0.704
# [epoch: 1, i:   899] avg mini-batch loss:  0.699
# [epoch: 1, i:   999] avg mini-batch loss:  0.701
# [epoch: 1, i:  1099] avg mini-batch loss:  0.699
# [epoch: 1, i:  1199] avg mini-batch loss:  0.685
# [epoch: 1, i:  1299] avg mini-batch loss:  0.699
# [epoch: 1, i:  1399] avg mini-batch loss:  0.700
# [epoch: 1, i:  1499] avg mini-batch loss:  0.700
# [epoch: 1, i:  1599] avg mini-batch loss:  0.700
# [epoch: 1, i:  1699] avg mini-batch loss:  0.694
# [epoch: 1, i:  1799] avg mini-batch loss:  0.688
# [epoch: 1, i:  1899] avg mini-batch loss:  0.693
# [epoch: 1, i:  1999] avg mini-batch loss:  0.699
# [epoch: 1, i:  2099] avg mini-batch loss:  0.702
# [epoch: 1, i:  2199] avg mini-batch loss:  0.693
# [epoch: 1, i:  2299] avg mini-batch loss:  0.706
# [epoch: 1, i:  2399] avg mini-batch loss:  0.699
# [epoch: 1, i:  2499] avg mini-batch loss:  0.696
# [epoch: 1, i:  2599] avg mini-batch loss:  0.681
# [epoch: 1, i:  2699] avg mini-batch loss:  0.703
# [epoch: 1, i:  2799] avg mini-batch loss:  0.700
# [epoch: 1, i:  2899] avg mini-batch loss:  0.696
# [epoch: 1, i:  2999] avg mini-batch loss:  0.700
# [epoch: 1, i:  3099] avg mini-batch loss:  0.697
# [epoch: 1, i:  3199] avg mini-batch loss:  0.696
# [epoch: 1, i:  3299] avg mini-batch loss:  0.700
# [epoch: 1, i:  3399] avg mini-batch loss:  0.694
# [epoch: 1, i:  3499] avg mini-batch loss:  0.699
# [epoch: 1, i:  3599] avg mini-batch loss:  0.695
# [epoch: 1, i:  3699] avg mini-batch loss:  0.696
# [epoch: 2, i:    99] avg mini-batch loss:  0.702
# [epoch: 2, i:   199] avg mini-batch loss:  0.695
# [epoch: 2, i:   299] avg mini-batch loss:  0.703
# [epoch: 2, i:   399] avg mini-batch loss:  0.700
# [epoch: 2, i:   499] avg mini-batch loss:  0.700
# [epoch: 2, i:   599] avg mini-batch loss:  0.692
# [epoch: 2, i:   699] avg mini-batch loss:  0.703
# [epoch: 2, i:   799] avg mini-batch loss:  0.699
# [epoch: 2, i:   899] avg mini-batch loss:  0.697
# [epoch: 2, i:   999] avg mini-batch loss:  0.701
# [epoch: 2, i:  1099] avg mini-batch loss:  0.701
# [epoch: 2, i:  1199] avg mini-batch loss:  0.690
# [epoch: 2, i:  1299] avg mini-batch loss:  0.687
# [epoch: 2, i:  1399] avg mini-batch loss:  0.677
# [epoch: 2, i:  1499] avg mini-batch loss:  0.712
# [epoch: 2, i:  1599] avg mini-batch loss:  0.700
# [epoch: 2, i:  1699] avg mini-batch loss:  0.699
# [epoch: 2, i:  1799] avg mini-batch loss:  0.695
# [epoch: 2, i:  1899] avg mini-batch loss:  0.699
# [epoch: 2, i:  1999] avg mini-batch loss:  0.697
# [epoch: 2, i:  2099] avg mini-batch loss:  0.677
# [epoch: 2, i:  2199] avg mini-batch loss:  0.707
# [epoch: 2, i:  2299] avg mini-batch loss:  0.692
# [epoch: 2, i:  2399] avg mini-batch loss:  0.704
# [epoch: 2, i:  2499] avg mini-batch loss:  0.694
# [epoch: 2, i:  2599] avg mini-batch loss:  0.695
# [epoch: 2, i:  2699] avg mini-batch loss:  0.702
# [epoch: 2, i:  2799] avg mini-batch loss:  0.701
# [epoch: 2, i:  2899] avg mini-batch loss:  0.685
# [epoch: 2, i:  2999] avg mini-batch loss:  0.686
# [epoch: 2, i:  3099] avg mini-batch loss:  0.707
# [epoch: 2, i:  3199] avg mini-batch loss:  0.699
# [epoch: 2, i:  3299] avg mini-batch loss:  0.694
# [epoch: 2, i:  3399] avg mini-batch loss:  0.700
# [epoch: 2, i:  3499] avg mini-batch loss:  0.698
# [epoch: 2, i:  3599] avg mini-batch loss:  0.702
# [epoch: 2, i:  3699] avg mini-batch loss:  0.698
# [epoch: 3, i:    99] avg mini-batch loss:  0.698
# [epoch: 3, i:   199] avg mini-batch loss:  0.699
# [epoch: 3, i:   299] avg mini-batch loss:  0.700
# [epoch: 3, i:   399] avg mini-batch loss:  0.698
# [epoch: 3, i:   499] avg mini-batch loss:  0.694
# [epoch: 3, i:   599] avg mini-batch loss:  0.701
# [epoch: 3, i:   699] avg mini-batch loss:  0.697
# [epoch: 3, i:   799] avg mini-batch loss:  0.700
# [epoch: 3, i:   899] avg mini-batch loss:  0.701
# [epoch: 3, i:   999] avg mini-batch loss:  0.700
# [epoch: 3, i:  1099] avg mini-batch loss:  0.693
# [epoch: 3, i:  1199] avg mini-batch loss:  0.698
# [epoch: 3, i:  1299] avg mini-batch loss:  0.700
# [epoch: 3, i:  1399] avg mini-batch loss:  0.691
# [epoch: 3, i:  1499] avg mini-batch loss:  0.702
# [epoch: 3, i:  1599] avg mini-batch loss:  0.684
# [epoch: 3, i:  1699] avg mini-batch loss:  0.704
# [epoch: 3, i:  1799] avg mini-batch loss:  0.698
# [epoch: 3, i:  1899] avg mini-batch loss:  0.700
# [epoch: 3, i:  1999] avg mini-batch loss:  0.701
# [epoch: 3, i:  2099] avg mini-batch loss:  0.700
# [epoch: 3, i:  2199] avg mini-batch loss:  0.687
# [epoch: 3, i:  2299] avg mini-batch loss:  0.698
# [epoch: 3, i:  2399] avg mini-batch loss:  0.681
# [epoch: 3, i:  2499] avg mini-batch loss:  0.706
# [epoch: 3, i:  2599] avg mini-batch loss:  0.698
# [epoch: 3, i:  2699] avg mini-batch loss:  0.700
# [epoch: 3, i:  2799] avg mini-batch loss:  0.685
# [epoch: 3, i:  2899] avg mini-batch loss:  0.701
# [epoch: 3, i:  2999] avg mini-batch loss:  0.693
# [epoch: 3, i:  3099] avg mini-batch loss:  0.705
# [epoch: 3, i:  3199] avg mini-batch loss:  0.698
# [epoch: 3, i:  3299] avg mini-batch loss:  0.701
# [epoch: 3, i:  3399] avg mini-batch loss:  0.679
# [epoch: 3, i:  3499] avg mini-batch loss:  0.680
# [epoch: 3, i:  3599] avg mini-batch loss:  0.704
# [epoch: 3, i:  3699] avg mini-batch loss:  0.701
# [epoch: 4, i:    99] avg mini-batch loss:  0.700
# [epoch: 4, i:   199] avg mini-batch loss:  0.696
# [epoch: 4, i:   299] avg mini-batch loss:  0.701
# [epoch: 4, i:   399] avg mini-batch loss:  0.700
# [epoch: 4, i:   499] avg mini-batch loss:  0.699
# [epoch: 4, i:   599] avg mini-batch loss:  0.699
# [epoch: 4, i:   699] avg mini-batch loss:  0.700
# [epoch: 4, i:   799] avg mini-batch loss:  0.699
# [epoch: 4, i:   899] avg mini-batch loss:  0.695
# [epoch: 4, i:   999] avg mini-batch loss:  0.697
# [epoch: 4, i:  1099] avg mini-batch loss:  0.701
# [epoch: 4, i:  1199] avg mini-batch loss:  0.700
# [epoch: 4, i:  1299] avg mini-batch loss:  0.692
# [epoch: 4, i:  1399] avg mini-batch loss:  0.708
# [epoch: 4, i:  1499] avg mini-batch loss:  0.699
# [epoch: 4, i:  1599] avg mini-batch loss:  0.702
# [epoch: 4, i:  1699] avg mini-batch loss:  0.700
# [epoch: 4, i:  1799] avg mini-batch loss:  0.657
# [epoch: 4, i:  1899] avg mini-batch loss:  0.707
# [epoch: 4, i:  1999] avg mini-batch loss:  0.691
# [epoch: 4, i:  2099] avg mini-batch loss:  0.702
# [epoch: 4, i:  2199] avg mini-batch loss:  0.700
# [epoch: 4, i:  2299] avg mini-batch loss:  0.693
# [epoch: 4, i:  2399] avg mini-batch loss:  0.704
# [epoch: 4, i:  2499] avg mini-batch loss:  0.698
# [epoch: 4, i:  2599] avg mini-batch loss:  0.697
# [epoch: 4, i:  2699] avg mini-batch loss:  0.700
# [epoch: 4, i:  2799] avg mini-batch loss:  0.697
# [epoch: 4, i:  2899] avg mini-batch loss:  0.702
# [epoch: 4, i:  2999] avg mini-batch loss:  0.700
# [epoch: 4, i:  3099] avg mini-batch loss:  0.694
# [epoch: 4, i:  3199] avg mini-batch loss:  0.704
# [epoch: 4, i:  3299] avg mini-batch loss:  0.700
# [epoch: 4, i:  3399] avg mini-batch loss:  0.689
# [epoch: 4, i:  3499] avg mini-batch loss:  0.699
# [epoch: 4, i:  3599] avg mini-batch loss:  0.701
# [epoch: 4, i:  3699] avg mini-batch loss:  0.696
# [epoch: 5, i:    99] avg mini-batch loss:  0.712
# [epoch: 5, i:   199] avg mini-batch loss:  0.701
# [epoch: 5, i:   299] avg mini-batch loss:  0.687
# [epoch: 5, i:   399] avg mini-batch loss:  0.699
# [epoch: 5, i:   499] avg mini-batch loss:  0.705
# [epoch: 5, i:   599] avg mini-batch loss:  0.696
# [epoch: 5, i:   699] avg mini-batch loss:  0.703
# [epoch: 5, i:   799] avg mini-batch loss:  0.692
# [epoch: 5, i:   899] avg mini-batch loss:  0.704
# [epoch: 5, i:   999] avg mini-batch loss:  0.690
# [epoch: 5, i:  1099] avg mini-batch loss:  0.699
# [epoch: 5, i:  1199] avg mini-batch loss:  0.697
# [epoch: 5, i:  1299] avg mini-batch loss:  0.686
# [epoch: 5, i:  1399] avg mini-batch loss:  0.706
# [epoch: 5, i:  1499] avg mini-batch loss:  0.675
# [epoch: 5, i:  1599] avg mini-batch loss:  0.702
# [epoch: 5, i:  1699] avg mini-batch loss:  0.700
# [epoch: 5, i:  1799] avg mini-batch loss:  0.702
# [epoch: 5, i:  1899] avg mini-batch loss:  0.700
# [epoch: 5, i:  1999] avg mini-batch loss:  0.701
# [epoch: 5, i:  2099] avg mini-batch loss:  0.700
# [epoch: 5, i:  2199] avg mini-batch loss:  0.700
# [epoch: 5, i:  2299] avg mini-batch loss:  0.699
# [epoch: 5, i:  2399] avg mini-batch loss:  0.701
# [epoch: 5, i:  2499] avg mini-batch loss:  0.700
# [epoch: 5, i:  2599] avg mini-batch loss:  0.700
# [epoch: 5, i:  2699] avg mini-batch loss:  0.688
# [epoch: 5, i:  2799] avg mini-batch loss:  0.697
# [epoch: 5, i:  2899] avg mini-batch loss:  0.700
# [epoch: 5, i:  2999] avg mini-batch loss:  0.698
# [epoch: 5, i:  3099] avg mini-batch loss:  0.700
# [epoch: 5, i:  3199] avg mini-batch loss:  0.699
# [epoch: 5, i:  3299] avg mini-batch loss:  0.699
# [epoch: 5, i:  3399] avg mini-batch loss:  0.701
# [epoch: 5, i:  3499] avg mini-batch loss:  0.701
# [epoch: 5, i:  3599] avg mini-batch loss:  0.687
# [epoch: 5, i:  3699] avg mini-batch loss:  0.678
# [epoch: 6, i:    99] avg mini-batch loss:  0.690
# [epoch: 6, i:   199] avg mini-batch loss:  0.704
# [epoch: 6, i:   299] avg mini-batch loss:  0.685
# [epoch: 6, i:   399] avg mini-batch loss:  0.688
# [epoch: 6, i:   499] avg mini-batch loss:  0.690
# [epoch: 6, i:   599] avg mini-batch loss:  0.702
# [epoch: 6, i:   699] avg mini-batch loss:  0.700
# [epoch: 6, i:   799] avg mini-batch loss:  0.697
# [epoch: 6, i:   899] avg mini-batch loss:  0.697
# [epoch: 6, i:   999] avg mini-batch loss:  0.701
# [epoch: 6, i:  1099] avg mini-batch loss:  0.699
# [epoch: 6, i:  1199] avg mini-batch loss:  0.697
# [epoch: 6, i:  1299] avg mini-batch loss:  0.693
# [epoch: 6, i:  1399] avg mini-batch loss:  0.704
# [epoch: 6, i:  1499] avg mini-batch loss:  0.700
# [epoch: 6, i:  1599] avg mini-batch loss:  0.699
# [epoch: 6, i:  1699] avg mini-batch loss:  0.700
# [epoch: 6, i:  1799] avg mini-batch loss:  0.700
# [epoch: 6, i:  1899] avg mini-batch loss:  0.698
# [epoch: 6, i:  1999] avg mini-batch loss:  0.695
# [epoch: 6, i:  2099] avg mini-batch loss:  0.686
# [epoch: 6, i:  2199] avg mini-batch loss:  0.698
# [epoch: 6, i:  2299] avg mini-batch loss:  0.699
# [epoch: 6, i:  2399] avg mini-batch loss:  0.694
# [epoch: 6, i:  2499] avg mini-batch loss:  0.700
# [epoch: 6, i:  2599] avg mini-batch loss:  0.691
# [epoch: 6, i:  2699] avg mini-batch loss:  0.700
# [epoch: 6, i:  2799] avg mini-batch loss:  0.699
# [epoch: 6, i:  2899] avg mini-batch loss:  0.693
# [epoch: 6, i:  2999] avg mini-batch loss:  0.695
# [epoch: 6, i:  3099] avg mini-batch loss:  0.695
# [epoch: 6, i:  3199] avg mini-batch loss:  0.700
# [epoch: 6, i:  3299] avg mini-batch loss:  0.701
# [epoch: 6, i:  3399] avg mini-batch loss:  0.700
# [epoch: 6, i:  3499] avg mini-batch loss:  0.693
# [epoch: 6, i:  3599] avg mini-batch loss:  0.696
# [epoch: 6, i:  3699] avg mini-batch loss:  0.699
# [epoch: 7, i:    99] avg mini-batch loss:  0.707
# [epoch: 7, i:   199] avg mini-batch loss:  0.699
# [epoch: 7, i:   299] avg mini-batch loss:  0.689
# [epoch: 7, i:   399] avg mini-batch loss:  0.686
# [epoch: 7, i:   499] avg mini-batch loss:  0.697
# [epoch: 7, i:   599] avg mini-batch loss:  0.689
# [epoch: 7, i:   699] avg mini-batch loss:  0.700
# [epoch: 7, i:   799] avg mini-batch loss:  0.695
# [epoch: 7, i:   899] avg mini-batch loss:  0.700
# [epoch: 7, i:   999] avg mini-batch loss:  0.696
# [epoch: 7, i:  1099] avg mini-batch loss:  0.692
# [epoch: 7, i:  1199] avg mini-batch loss:  0.693
# [epoch: 7, i:  1299] avg mini-batch loss:  0.703
# [epoch: 7, i:  1399] avg mini-batch loss:  0.685
# [epoch: 7, i:  1499] avg mini-batch loss:  0.704
# [epoch: 7, i:  1599] avg mini-batch loss:  0.700
# [epoch: 7, i:  1699] avg mini-batch loss:  0.699
# [epoch: 7, i:  1799] avg mini-batch loss:  0.694
# [epoch: 7, i:  1899] avg mini-batch loss:  0.699
# [epoch: 7, i:  1999] avg mini-batch loss:  0.691
# [epoch: 7, i:  2099] avg mini-batch loss:  0.703
# [epoch: 7, i:  2199] avg mini-batch loss:  0.684
# [epoch: 7, i:  2299] avg mini-batch loss:  0.704
# [epoch: 7, i:  2399] avg mini-batch loss:  0.681
# [epoch: 7, i:  2499] avg mini-batch loss:  0.709
# [epoch: 7, i:  2599] avg mini-batch loss:  0.697
# [epoch: 7, i:  2699] avg mini-batch loss:  0.689
# [epoch: 7, i:  2799] avg mini-batch loss:  0.698
# [epoch: 7, i:  2899] avg mini-batch loss:  0.701
# [epoch: 7, i:  2999] avg mini-batch loss:  0.700
# [epoch: 7, i:  3099] avg mini-batch loss:  0.698
# [epoch: 7, i:  3199] avg mini-batch loss:  0.701
# [epoch: 7, i:  3299] avg mini-batch loss:  0.700
# [epoch: 7, i:  3399] avg mini-batch loss:  0.699
# [epoch: 7, i:  3499] avg mini-batch loss:  0.693
# [epoch: 7, i:  3599] avg mini-batch loss:  0.697
# [epoch: 7, i:  3699] avg mini-batch loss:  0.704
# [epoch: 8, i:    99] avg mini-batch loss:  0.697
# [epoch: 8, i:   199] avg mini-batch loss:  0.699
# [epoch: 8, i:   299] avg mini-batch loss:  0.687
# [epoch: 8, i:   399] avg mini-batch loss:  0.707
# [epoch: 8, i:   499] avg mini-batch loss:  0.698
# [epoch: 8, i:   599] avg mini-batch loss:  0.691
# [epoch: 8, i:   699] avg mini-batch loss:  0.702
# [epoch: 8, i:   799] avg mini-batch loss:  0.685
# [epoch: 8, i:   899] avg mini-batch loss:  0.688
# [epoch: 8, i:   999] avg mini-batch loss:  0.705
# [epoch: 8, i:  1099] avg mini-batch loss:  0.696
# [epoch: 8, i:  1199] avg mini-batch loss:  0.680
# [epoch: 8, i:  1299] avg mini-batch loss:  0.701
# [epoch: 8, i:  1399] avg mini-batch loss:  0.695
# [epoch: 8, i:  1499] avg mini-batch loss:  0.699
# [epoch: 8, i:  1599] avg mini-batch loss:  0.701
# [epoch: 8, i:  1699] avg mini-batch loss:  0.675
# [epoch: 8, i:  1799] avg mini-batch loss:  0.713
# [epoch: 8, i:  1899] avg mini-batch loss:  0.689
# [epoch: 8, i:  1999] avg mini-batch loss:  0.700
# [epoch: 8, i:  2099] avg mini-batch loss:  0.696
# [epoch: 8, i:  2199] avg mini-batch loss:  0.704
# [epoch: 8, i:  2299] avg mini-batch loss:  0.700
# [epoch: 8, i:  2399] avg mini-batch loss:  0.700
# [epoch: 8, i:  2499] avg mini-batch loss:  0.698
# [epoch: 8, i:  2599] avg mini-batch loss:  0.701
# [epoch: 8, i:  2699] avg mini-batch loss:  0.697
# [epoch: 8, i:  2799] avg mini-batch loss:  0.697
# [epoch: 8, i:  2899] avg mini-batch loss:  0.696
# [epoch: 8, i:  2999] avg mini-batch loss:  0.699
# [epoch: 8, i:  3099] avg mini-batch loss:  0.699
# [epoch: 8, i:  3199] avg mini-batch loss:  0.697
# [epoch: 8, i:  3299] avg mini-batch loss:  0.695
# [epoch: 8, i:  3399] avg mini-batch loss:  0.698
# [epoch: 8, i:  3499] avg mini-batch loss:  0.701
# [epoch: 8, i:  3599] avg mini-batch loss:  0.696
# [epoch: 8, i:  3699] avg mini-batch loss:  0.701
# [epoch: 9, i:    99] avg mini-batch loss:  0.695
# [epoch: 9, i:   199] avg mini-batch loss:  0.696
# [epoch: 9, i:   299] avg mini-batch loss:  0.702
# [epoch: 9, i:   399] avg mini-batch loss:  0.700
# [epoch: 9, i:   499] avg mini-batch loss:  0.698
# [epoch: 9, i:   599] avg mini-batch loss:  0.698
# [epoch: 9, i:   699] avg mini-batch loss:  0.701
# [epoch: 9, i:   799] avg mini-batch loss:  0.697
# [epoch: 9, i:   899] avg mini-batch loss:  0.690
# [epoch: 9, i:   999] avg mini-batch loss:  0.698
# [epoch: 9, i:  1099] avg mini-batch loss:  0.700
# [epoch: 9, i:  1199] avg mini-batch loss:  0.698
# [epoch: 9, i:  1299] avg mini-batch loss:  0.695
# [epoch: 9, i:  1399] avg mini-batch loss:  0.702
# [epoch: 9, i:  1499] avg mini-batch loss:  0.701
# [epoch: 9, i:  1599] avg mini-batch loss:  0.695
# [epoch: 9, i:  1699] avg mini-batch loss:  0.703
# [epoch: 9, i:  1799] avg mini-batch loss:  0.691
# [epoch: 9, i:  1899] avg mini-batch loss:  0.698
# [epoch: 9, i:  1999] avg mini-batch loss:  0.694
# [epoch: 9, i:  2099] avg mini-batch loss:  0.700
# [epoch: 9, i:  2199] avg mini-batch loss:  0.699
# [epoch: 9, i:  2299] avg mini-batch loss:  0.681
# [epoch: 9, i:  2399] avg mini-batch loss:  0.709
# [epoch: 9, i:  2499] avg mini-batch loss:  0.695
# [epoch: 9, i:  2599] avg mini-batch loss:  0.700
# [epoch: 9, i:  2699] avg mini-batch loss:  0.695
# [epoch: 9, i:  2799] avg mini-batch loss:  0.701
# [epoch: 9, i:  2899] avg mini-batch loss:  0.696
# [epoch: 9, i:  2999] avg mini-batch loss:  0.701
# [epoch: 9, i:  3099] avg mini-batch loss:  0.678
# [epoch: 9, i:  3199] avg mini-batch loss:  0.705
# [epoch: 9, i:  3299] avg mini-batch loss:  0.696
# [epoch: 9, i:  3399] avg mini-batch loss:  0.693
# [epoch: 9, i:  3499] avg mini-batch loss:  0.701
# [epoch: 9, i:  3599] avg mini-batch loss:  0.702
# [epoch: 9, i:  3699] avg mini-batch loss:  0.692
# Finished Training.

# %%
# training loss curve
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# test the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for spectrograms, labels in test_loader:
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        outputs = model(spectrograms)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Accuracy: 50.0%
