# %% [markdown]
# #Convolutional Neural Networks for Audio Detection
# ## Setting Up

# %%
# copy from drive to working directory
# !cp -r /content/drive/MyDrive/COGS181_DATA /content/COGS181

# %%
# libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torchaudio
import os
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt

# %%
# audio (WAV) files
## train
train_real_path = "/content/COGS181/train_real"
train_fake_path = "/content/COGS181/train_fake"

## test
test_real_path  = "/content/COGS181/test_real"
test_fake_path  = "/content/COGS181/test_fake"

# %%
# get the files from the folder to use
def file_to_folder(folder, label):
  files = []
  labels = []
  for filename in os.listdir(folder):
    # Exclude macOS resource fork files that start with '._'
    if filename.lower().endswith(".wav") and not filename.startswith('._'):
      files.append(os.path.join(folder, filename))
      labels.append(label)
  return files, labels

# get files and labels
## train
train_real_files, train_real_labels = file_to_folder(train_real_path, 0)
train_fake_files, train_fake_labels = file_to_folder(train_fake_path, 1)


## test
test_real_files, test_real_labels = file_to_folder(test_real_path, 0)
test_fake_files, test_fake_labels = file_to_folder(test_fake_path, 1)

## combine for train, validation, and test datasets
train_files = train_real_files + train_fake_files
train_labels = train_real_labels + train_fake_labels

test_files = test_real_files + test_fake_files
test_labels = test_real_labels + test_fake_labels

len(train_files), len(test_files)
# Out:
# (3750, 1250)

# %%
# define audiodataset
class AudioDataset(Dataset):
    def __init__(self, audio_files, labels):
        self.audio_files = audio_files
        self.labels = labels
        self.transform = torchaudio.transforms.Spectrogram()

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        waveform, _ = torchaudio.load(self.audio_files[idx])
        spectrogram = self.transform(waveform)
        label = self.labels[idx]
        return spectrogram, label

# %%
# getting the train/test dataset and loader
train_dataset = AudioDataset(train_files, train_labels)
test_dataset = AudioDataset(test_files, test_labels)

train_loader = DataLoader(train_dataset, batch_size = 1, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = 1)

# %% [markdown]
# # Neural Network IX
# Total layers: 7
#
# Activation function: ReLU
#
# Pooling functions: max pooling, adaptive average pool
#
# Optimization: Adam
#
# Regularization: Dropout
#
# Normalization: N/A

# %%
# audio CNN definition
class AudioCNN(nn.Module):
    def __init__(self):
        super(AudioCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size = 3, padding = 1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size = 3, padding = 1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size = 3, padding = 1)

        self.pool = nn.MaxPool2d(2)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.fc1 = nn.Linear(128 * 1 * 1, 128)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = self.avg_pool(x)
        x = x.view(-1, 128 * 1 * 1)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

model = AudioCNN()

# %%
# loss function and optimizer
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

# %%
# training the model
avg_losses = []
num_epochs = 10
print_freq = 100

for epoch in range(num_epochs):
    model.train()

    running_loss = 0.0
    for i, (spectrograms, labels) in enumerate(train_loader, 0):
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        optimizer.zero_grad()
        outputs = model(spectrograms)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # not in original article but added for consistency
        if i % print_freq == print_freq - 1:
          avg_loss = running_loss / print_freq
          print("[epoch: {}, i: {:5d}] avg mini-batch loss: {: .3f}".format(epoch, i, avg_loss))
          avg_losses.append(avg_loss)
          running_loss = 0.0

print("Finished Training.")
# Out:
# [epoch: 0, i:    99] avg mini-batch loss:  0.756
# [epoch: 0, i:   199] avg mini-batch loss:  0.606
# [epoch: 0, i:   299] avg mini-batch loss:  0.612
# [epoch: 0, i:   399] avg mini-batch loss:  0.600
# [epoch: 0, i:   499] avg mini-batch loss:  0.605
# [epoch: 0, i:   599] avg mini-batch loss:  0.612
# [epoch: 0, i:   699] avg mini-batch loss:  0.586
# [epoch: 0, i:   799] avg mini-batch loss:  0.562
# [epoch: 0, i:   899] avg mini-batch loss:  0.521
# [epoch: 0, i:   999] avg mini-batch loss:  0.527
# [epoch: 0, i:  1099] avg mini-batch loss:  0.617
# [epoch: 0, i:  1199] avg mini-batch loss:  0.579
# [epoch: 0, i:  1299] avg mini-batch loss:  0.595
# [epoch: 0, i:  1399] avg mini-batch loss:  0.608
# [epoch: 0, i:  1499] avg mini-batch loss:  0.527
# [epoch: 0, i:  1599] avg mini-batch loss:  0.548
# [epoch: 0, i:  1699] avg mini-batch loss:  0.550
# [epoch: 0, i:  1799] avg mini-batch loss:  0.560
# [epoch: 0, i:  1899] avg mini-batch loss:  0.561
# [epoch: 0, i:  1999] avg mini-batch loss:  0.610
# [epoch: 0, i:  2099] avg mini-batch loss:  0.556
# [epoch: 0, i:  2199] avg mini-batch loss:  0.525
# [epoch: 0, i:  2299] avg mini-batch loss:  1.015
# [epoch: 0, i:  2399] avg mini-batch loss:  0.700
# [epoch: 0, i:  2499] avg mini-batch loss:  0.567
# [epoch: 0, i:  2599] avg mini-batch loss:  0.596
# [epoch: 0, i:  2699] avg mini-batch loss:  0.550
# [epoch: 0, i:  2799] avg mini-batch loss:  0.528
# [epoch: 0, i:  2899] avg mini-batch loss:  0.536
# [epoch: 0, i:  2999] avg mini-batch loss:  0.538
# [epoch: 0, i:  3099] avg mini-batch loss:  0.586
# [epoch: 0, i:  3199] avg mini-batch loss:  0.515
# [epoch: 0, i:  3299] avg mini-batch loss:  0.525
# [epoch: 0, i:  3399] avg mini-batch loss:  0.543
# [epoch: 0, i:  3499] avg mini-batch loss:  0.551
# [epoch: 0, i:  3599] avg mini-batch loss:  0.518
# [epoch: 0, i:  3699] avg mini-batch loss:  0.526
# [epoch: 1, i:    99] avg mini-batch loss:  0.537
# [epoch: 1, i:   199] avg mini-batch loss:  0.532
# [epoch: 1, i:   299] avg mini-batch loss:  0.421
# [epoch: 1, i:   399] avg mini-batch loss:  0.504
# [epoch: 1, i:   499] avg mini-batch loss:  0.448
# [epoch: 1, i:   599] avg mini-batch loss:  0.628
# [epoch: 1, i:   699] avg mini-batch loss:  0.625
# [epoch: 1, i:   799] avg mini-batch loss:  0.590
# [epoch: 1, i:   899] avg mini-batch loss:  0.510
# [epoch: 1, i:   999] avg mini-batch loss:  0.523
# [epoch: 1, i:  1099] avg mini-batch loss:  0.554
# [epoch: 1, i:  1199] avg mini-batch loss:  0.545
# [epoch: 1, i:  1299] avg mini-batch loss:  0.485
# [epoch: 1, i:  1399] avg mini-batch loss:  0.454
# [epoch: 1, i:  1499] avg mini-batch loss:  0.533
# [epoch: 1, i:  1599] avg mini-batch loss:  0.447
# [epoch: 1, i:  1699] avg mini-batch loss:  0.498
# [epoch: 1, i:  1799] avg mini-batch loss:  0.438
# [epoch: 1, i:  1899] avg mini-batch loss:  0.574
# [epoch: 1, i:  1999] avg mini-batch loss:  0.519
# [epoch: 1, i:  2099] avg mini-batch loss:  0.404
# [epoch: 1, i:  2199] avg mini-batch loss:  0.425
# [epoch: 1, i:  2299] avg mini-batch loss:  0.376
# [epoch: 1, i:  2399] avg mini-batch loss:  0.372
# [epoch: 1, i:  2499] avg mini-batch loss:  0.368
# [epoch: 1, i:  2599] avg mini-batch loss:  0.787
# [epoch: 1, i:  2699] avg mini-batch loss:  0.494
# [epoch: 1, i:  2799] avg mini-batch loss:  0.525
# [epoch: 1, i:  2899] avg mini-batch loss:  0.439
# [epoch: 1, i:  2999] avg mini-batch loss:  0.367
# [epoch: 1, i:  3099] avg mini-batch loss:  0.405
# [epoch: 1, i:  3199] avg mini-batch loss:  0.657
# [epoch: 1, i:  3299] avg mini-batch loss:  0.477
# [epoch: 1, i:  3399] avg mini-batch loss:  0.433
# [epoch: 1, i:  3499] avg mini-batch loss:  0.394
# [epoch: 1, i:  3599] avg mini-batch loss:  0.400
# [epoch: 1, i:  3699] avg mini-batch loss:  0.403
# [epoch: 2, i:    99] avg mini-batch loss:  0.365
# [epoch: 2, i:   199] avg mini-batch loss:  0.314
# [epoch: 2, i:   299] avg mini-batch loss:  0.281
# [epoch: 2, i:   399] avg mini-batch loss:  0.368
# [epoch: 2, i:   499] avg mini-batch loss:  0.805
# [epoch: 2, i:   599] avg mini-batch loss:  0.381
# [epoch: 2, i:   699] avg mini-batch loss:  0.381
# [epoch: 2, i:   799] avg mini-batch loss:  0.398
# [epoch: 2, i:   899] avg mini-batch loss:  0.281
# [epoch: 2, i:   999] avg mini-batch loss:  0.359
# [epoch: 2, i:  1099] avg mini-batch loss:  0.349
# [epoch: 2, i:  1199] avg mini-batch loss:  0.233
# [epoch: 2, i:  1299] avg mini-batch loss:  0.256
# [epoch: 2, i:  1399] avg mini-batch loss:  0.209
# [epoch: 2, i:  1499] avg mini-batch loss:  0.188
# [epoch: 2, i:  1599] avg mini-batch loss:  0.261
# [epoch: 2, i:  1699] avg mini-batch loss:  0.163
# [epoch: 2, i:  1799] avg mini-batch loss:  0.145
# [epoch: 2, i:  1899] avg mini-batch loss:  0.244
# [epoch: 2, i:  1999] avg mini-batch loss:  0.904
# [epoch: 2, i:  2099] avg mini-batch loss:  0.236
# [epoch: 2, i:  2199] avg mini-batch loss:  0.257
# [epoch: 2, i:  2299] avg mini-batch loss:  0.212
# [epoch: 2, i:  2399] avg mini-batch loss:  0.406
# [epoch: 2, i:  2499] avg mini-batch loss:  0.229
# [epoch: 2, i:  2599] avg mini-batch loss:  0.248
# [epoch: 2, i:  2699] avg mini-batch loss:  0.208
# [epoch: 2, i:  2799] avg mini-batch loss:  0.219
# [epoch: 2, i:  2899] avg mini-batch loss:  0.160
# [epoch: 2, i:  2999] avg mini-batch loss:  0.147
# [epoch: 2, i:  3099] avg mini-batch loss:  0.216
# [epoch: 2, i:  3199] avg mini-batch loss:  0.251
# [epoch: 2, i:  3299] avg mini-batch loss:  0.169
# [epoch: 2, i:  3399] avg mini-batch loss:  0.158
# [epoch: 2, i:  3499] avg mini-batch loss:  0.418
# [epoch: 2, i:  3599] avg mini-batch loss:  0.315
# [epoch: 2, i:  3699] avg mini-batch loss:  0.220
# [epoch: 3, i:    99] avg mini-batch loss:  0.157
# [epoch: 3, i:   199] avg mini-batch loss:  0.145
# [epoch: 3, i:   299] avg mini-batch loss:  0.148
# [epoch: 3, i:   399] avg mini-batch loss:  0.696
# [epoch: 3, i:   499] avg mini-batch loss:  0.305
# [epoch: 3, i:   599] avg mini-batch loss:  0.245
# [epoch: 3, i:   699] avg mini-batch loss:  0.172
# [epoch: 3, i:   799] avg mini-batch loss:  0.135
# [epoch: 3, i:   899] avg mini-batch loss:  0.150
# [epoch: 3, i:   999] avg mini-batch loss:  0.154
# [epoch: 3, i:  1099] avg mini-batch loss:  0.123
# [epoch: 3, i:  1199] avg mini-batch loss:  0.131
# [epoch: 3, i:  1299] avg mini-batch loss:  0.168
# [epoch: 3, i:  1399] avg mini-batch loss:  0.113
# [epoch: 3, i:  1499] avg mini-batch loss:  0.105
# [epoch: 3, i:  1599] avg mini-batch loss:  0.146
# [epoch: 3, i:  1699] avg mini-batch loss:  0.257
# [epoch: 3, i:  1799] avg mini-batch loss:  0.132
# [epoch: 3, i:  1899] avg mini-batch loss:  0.398
# [epoch: 3, i:  1999] avg mini-batch loss:  0.187
# [epoch: 3, i:  2099] avg mini-batch loss:  0.232
# [epoch: 3, i:  2199] avg mini-batch loss:  0.188
# [epoch: 3, i:  2299] avg mini-batch loss:  0.160
# [epoch: 3, i:  2399] avg mini-batch loss:  0.099
# [epoch: 3, i:  2499] avg mini-batch loss:  0.117
# [epoch: 3, i:  2599] avg mini-batch loss:  0.092
# [epoch: 3, i:  2699] avg mini-batch loss:  0.121
# [epoch: 3, i:  2799] avg mini-batch loss:  0.058
# [epoch: 3, i:  2899] avg mini-batch loss:  0.161
# [epoch: 3, i:  2999] avg mini-batch loss:  0.073
# [epoch: 3, i:  3099] avg mini-batch loss:  0.077
# [epoch: 3, i:  3199] avg mini-batch loss:  1.079
# [epoch: 3, i:  3299] avg mini-batch loss:  0.323
# [epoch: 3, i:  3399] avg mini-batch loss:  0.279
# [epoch: 3, i:  3499] avg mini-batch loss:  0.288
# [epoch: 3, i:  3599] avg mini-batch loss:  0.181
# [epoch: 3, i:  3699] avg mini-batch loss:  0.138
# [epoch: 4, i:    99] avg mini-batch loss:  0.236
# [epoch: 4, i:   199] avg mini-batch loss:  0.253
# [epoch: 4, i:   299] avg mini-batch loss:  0.349
# [epoch: 4, i:   399] avg mini-batch loss:  0.383
# [epoch: 4, i:   499] avg mini-batch loss:  0.077
# [epoch: 4, i:   599] avg mini-batch loss:  0.043
# [epoch: 4, i:   699] avg mini-batch loss:  0.063
# [epoch: 4, i:   799] avg mini-batch loss:  0.061
# [epoch: 4, i:   899] avg mini-batch loss:  0.049
# [epoch: 4, i:   999] avg mini-batch loss:  0.062
# [epoch: 4, i:  1099] avg mini-batch loss:  0.096
# [epoch: 4, i:  1199] avg mini-batch loss:  0.036
# [epoch: 4, i:  1299] avg mini-batch loss:  0.061
# [epoch: 4, i:  1399] avg mini-batch loss:  0.070
# [epoch: 4, i:  1499] avg mini-batch loss:  0.197
# [epoch: 4, i:  1599] avg mini-batch loss:  0.084
# [epoch: 4, i:  1699] avg mini-batch loss:  0.030
# [epoch: 4, i:  1799] avg mini-batch loss:  0.068
# [epoch: 4, i:  1899] avg mini-batch loss:  0.038
# [epoch: 4, i:  1999] avg mini-batch loss:  0.007
# [epoch: 4, i:  2099] avg mini-batch loss:  0.017
# [epoch: 4, i:  2199] avg mini-batch loss:  0.032
# [epoch: 4, i:  2299] avg mini-batch loss:  0.008
# [epoch: 4, i:  2399] avg mini-batch loss:  0.008
# [epoch: 4, i:  2499] avg mini-batch loss:  0.496
# [epoch: 4, i:  2599] avg mini-batch loss:  0.193
# [epoch: 4, i:  2699] avg mini-batch loss:  0.144
# [epoch: 4, i:  2799] avg mini-batch loss:  0.158
# [epoch: 4, i:  2899] avg mini-batch loss:  0.092
# [epoch: 4, i:  2999] avg mini-batch loss:  0.197
# [epoch: 4, i:  3099] avg mini-batch loss:  0.071
# [epoch: 4, i:  3199] avg mini-batch loss:  0.045
# [epoch: 4, i:  3299] avg mini-batch loss:  0.068
# [epoch: 4, i:  3399] avg mini-batch loss:  0.051
# [epoch: 4, i:  3499] avg mini-batch loss:  0.181
# [epoch: 4, i:  3599] avg mini-batch loss:  0.040
# [epoch: 4, i:  3699] avg mini-batch loss:  0.070
# [epoch: 5, i:    99] avg mini-batch loss:  0.039
# [epoch: 5, i:   199] avg mini-batch loss:  0.024
# [epoch: 5, i:   299] avg mini-batch loss:  0.135
# [epoch: 5, i:   399] avg mini-batch loss:  0.039
# [epoch: 5, i:   499] avg mini-batch loss:  0.049
# [epoch: 5, i:   599] avg mini-batch loss:  0.013
# [epoch: 5, i:   699] avg mini-batch loss:  0.101
# [epoch: 5, i:   799] avg mini-batch loss:  0.034
# [epoch: 5, i:   899] avg mini-batch loss:  0.012
# [epoch: 5, i:   999] avg mini-batch loss:  0.013
# [epoch: 5, i:  1099] avg mini-batch loss:  0.108
# [epoch: 5, i:  1199] avg mini-batch loss:  0.052
# [epoch: 5, i:  1299] avg mini-batch loss:  0.097
# [epoch: 5, i:  1399] avg mini-batch loss:  0.036
# [epoch: 5, i:  1499] avg mini-batch loss:  0.011
# [epoch: 5, i:  1599] avg mini-batch loss:  0.013
# [epoch: 5, i:  1699] avg mini-batch loss:  0.018
# [epoch: 5, i:  1799] avg mini-batch loss:  0.007
# [epoch: 5, i:  1899] avg mini-batch loss:  0.008
# [epoch: 5, i:  1999] avg mini-batch loss:  0.021
# [epoch: 5, i:  2099] avg mini-batch loss:  0.011
# [epoch: 5, i:  2199] avg mini-batch loss:  0.007
# [epoch: 5, i:  2299] avg mini-batch loss:  0.014
# [epoch: 5, i:  2399] avg mini-batch loss:  0.005
# [epoch: 5, i:  2499] avg mini-batch loss:  0.002
# [epoch: 5, i:  2599] avg mini-batch loss:  0.044
# [epoch: 5, i:  2699] avg mini-batch loss:  0.008
# [epoch: 5, i:  2799] avg mini-batch loss:  0.009
# [epoch: 5, i:  2899] avg mini-batch loss:  0.002
# [epoch: 5, i:  2999] avg mini-batch loss:  0.001
# [epoch: 5, i:  3099] avg mini-batch loss:  0.002
# [epoch: 5, i:  3199] avg mini-batch loss:  0.021
# [epoch: 5, i:  3299] avg mini-batch loss:  0.151
# [epoch: 5, i:  3399] avg mini-batch loss:  0.026
# [epoch: 5, i:  3499] avg mini-batch loss:  0.525
# [epoch: 5, i:  3599] avg mini-batch loss:  0.048
# [epoch: 5, i:  3699] avg mini-batch loss:  0.014
# [epoch: 6, i:    99] avg mini-batch loss:  0.009
# [epoch: 6, i:   199] avg mini-batch loss:  0.007
# [epoch: 6, i:   299] avg mini-batch loss:  0.006
# [epoch: 6, i:   399] avg mini-batch loss:  0.005
# [epoch: 6, i:   499] avg mini-batch loss:  0.012
# [epoch: 6, i:   599] avg mini-batch loss:  0.009
# [epoch: 6, i:   699] avg mini-batch loss:  0.003
# [epoch: 6, i:   799] avg mini-batch loss:  0.004
# [epoch: 6, i:   899] avg mini-batch loss:  0.023
# [epoch: 6, i:   999] avg mini-batch loss:  0.003
# [epoch: 6, i:  1099] avg mini-batch loss:  0.003
# [epoch: 6, i:  1199] avg mini-batch loss:  0.004
# [epoch: 6, i:  1299] avg mini-batch loss:  0.003
# [epoch: 6, i:  1399] avg mini-batch loss:  0.001
# [epoch: 6, i:  1499] avg mini-batch loss:  0.001
# [epoch: 6, i:  1599] avg mini-batch loss:  0.001
# [epoch: 6, i:  1699] avg mini-batch loss:  0.001
# [epoch: 6, i:  1799] avg mini-batch loss:  0.005
# [epoch: 6, i:  1899] avg mini-batch loss:  0.004
# [epoch: 6, i:  1999] avg mini-batch loss:  0.002
# [epoch: 6, i:  2099] avg mini-batch loss:  0.002
# [epoch: 6, i:  2199] avg mini-batch loss:  0.044
# [epoch: 6, i:  2299] avg mini-batch loss:  0.213
# [epoch: 6, i:  2399] avg mini-batch loss:  0.123
# [epoch: 6, i:  2499] avg mini-batch loss:  0.041
# [epoch: 6, i:  2599] avg mini-batch loss:  0.066
# [epoch: 6, i:  2699] avg mini-batch loss:  0.010
# [epoch: 6, i:  2799] avg mini-batch loss:  0.008
# [epoch: 6, i:  2899] avg mini-batch loss:  0.007
# [epoch: 6, i:  2999] avg mini-batch loss:  0.003
# [epoch: 6, i:  3099] avg mini-batch loss:  0.032
# [epoch: 6, i:  3199] avg mini-batch loss:  0.005
# [epoch: 6, i:  3299] avg mini-batch loss:  0.033
# [epoch: 6, i:  3399] avg mini-batch loss:  0.016
# [epoch: 6, i:  3499] avg mini-batch loss:  0.005
# [epoch: 6, i:  3599] avg mini-batch loss:  0.003
# [epoch: 6, i:  3699] avg mini-batch loss:  0.004
# [epoch: 7, i:    99] avg mini-batch loss:  0.004
# [epoch: 7, i:   199] avg mini-batch loss:  0.003
# [epoch: 7, i:   299] avg mini-batch loss:  0.027
# [epoch: 7, i:   399] avg mini-batch loss:  0.006
# [epoch: 7, i:   499] avg mini-batch loss:  0.001
# [epoch: 7, i:   599] avg mini-batch loss:  0.002
# [epoch: 7, i:   699] avg mini-batch loss:  0.002
# [epoch: 7, i:   799] avg mini-batch loss:  0.002
# [epoch: 7, i:   899] avg mini-batch loss:  0.005
# [epoch: 7, i:   999] avg mini-batch loss:  0.005
# [epoch: 7, i:  1099] avg mini-batch loss:  0.003
# [epoch: 7, i:  1199] avg mini-batch loss:  0.001
# [epoch: 7, i:  1299] avg mini-batch loss:  0.002
# [epoch: 7, i:  1399] avg mini-batch loss:  0.001
# [epoch: 7, i:  1499] avg mini-batch loss:  0.001
# [epoch: 7, i:  1599] avg mini-batch loss:  0.001
# [epoch: 7, i:  1699] avg mini-batch loss:  0.000
# [epoch: 7, i:  1799] avg mini-batch loss:  0.003
# [epoch: 7, i:  1899] avg mini-batch loss:  0.011
# [epoch: 7, i:  1999] avg mini-batch loss:  0.239
# [epoch: 7, i:  2099] avg mini-batch loss:  0.225
# [epoch: 7, i:  2199] avg mini-batch loss:  0.082
# [epoch: 7, i:  2299] avg mini-batch loss:  0.010
# [epoch: 7, i:  2399] avg mini-batch loss:  0.068
# [epoch: 7, i:  2499] avg mini-batch loss:  0.021
# [epoch: 7, i:  2599] avg mini-batch loss:  0.005
# [epoch: 7, i:  2699] avg mini-batch loss:  0.024
# [epoch: 7, i:  2799] avg mini-batch loss:  0.014
# [epoch: 7, i:  2899] avg mini-batch loss:  0.004
# [epoch: 7, i:  2999] avg mini-batch loss:  0.106
# [epoch: 7, i:  3099] avg mini-batch loss:  0.007
# [epoch: 7, i:  3199] avg mini-batch loss:  0.046
# [epoch: 7, i:  3299] avg mini-batch loss:  0.025
# [epoch: 7, i:  3399] avg mini-batch loss:  0.002
# [epoch: 7, i:  3499] avg mini-batch loss:  0.003
# [epoch: 7, i:  3599] avg mini-batch loss:  0.002
# [epoch: 7, i:  3699] avg mini-batch loss:  0.006
# [epoch: 8, i:    99] avg mini-batch loss:  0.010
# [epoch: 8, i:   199] avg mini-batch loss:  0.058
# [epoch: 8, i:   299] avg mini-batch loss:  0.001
# [epoch: 8, i:   399] avg mini-batch loss:  0.001
# [epoch: 8, i:   499] avg mini-batch loss:  0.076
# [epoch: 8, i:   599] avg mini-batch loss:  0.025
# [epoch: 8, i:   699] avg mini-batch loss:  0.001
# [epoch: 8, i:   799] avg mini-batch loss:  0.003
# [epoch: 8, i:   899] avg mini-batch loss:  0.002
# [epoch: 8, i:   999] avg mini-batch loss:  0.128
# [epoch: 8, i:  1099] avg mini-batch loss:  0.014
# [epoch: 8, i:  1199] avg mini-batch loss:  0.044
# [epoch: 8, i:  1299] avg mini-batch loss:  0.005
# [epoch: 8, i:  1399] avg mini-batch loss:  0.004
# [epoch: 8, i:  1499] avg mini-batch loss:  0.044
# [epoch: 8, i:  1599] avg mini-batch loss:  0.041
# [epoch: 8, i:  1699] avg mini-batch loss:  0.003
# [epoch: 8, i:  1799] avg mini-batch loss:  0.060
# [epoch: 8, i:  1899] avg mini-batch loss:  0.029
# [epoch: 8, i:  1999] avg mini-batch loss:  0.225
# [epoch: 8, i:  2099] avg mini-batch loss:  0.084
# [epoch: 8, i:  2199] avg mini-batch loss:  0.023
# [epoch: 8, i:  2299] avg mini-batch loss:  0.004
# [epoch: 8, i:  2399] avg mini-batch loss:  0.004
# [epoch: 8, i:  2499] avg mini-batch loss:  0.002
# [epoch: 8, i:  2599] avg mini-batch loss:  0.009
# [epoch: 8, i:  2699] avg mini-batch loss:  0.002
# [epoch: 8, i:  2799] avg mini-batch loss:  0.002
# [epoch: 8, i:  2899] avg mini-batch loss:  0.004
# [epoch: 8, i:  2999] avg mini-batch loss:  0.001
# [epoch: 8, i:  3099] avg mini-batch loss:  0.001
# [epoch: 8, i:  3199] avg mini-batch loss:  0.003
# [epoch: 8, i:  3299] avg mini-batch loss:  0.001
# [epoch: 8, i:  3399] avg mini-batch loss:  0.001
# [epoch: 8, i:  3499] avg mini-batch loss:  0.000
# [epoch: 8, i:  3599] avg mini-batch loss:  0.001
# [epoch: 8, i:  3699] avg mini-batch loss:  0.001
# [epoch: 9, i:    99] avg mini-batch loss:  0.000
# [epoch: 9, i:   199] avg mini-batch loss:  0.000
# [epoch: 9, i:   299] avg mini-batch loss:  0.000
# [epoch: 9, i:   399] avg mini-batch loss:  0.105
# [epoch: 9, i:   499] avg mini-batch loss:  0.002
# [epoch: 9, i:   599] avg mini-batch loss:  0.001
# [epoch: 9, i:   699] avg mini-batch loss:  0.033
# [epoch: 9, i:   799] avg mini-batch loss:  0.008
# [epoch: 9, i:   899] avg mini-batch loss:  0.001
# [epoch: 9, i:   999] avg mini-batch loss:  0.007
# [epoch: 9, i:  1099] avg mini-batch loss:  0.001
# [epoch: 9, i:  1199] avg mini-batch loss:  0.013
# [epoch: 9, i:  1299] avg mini-batch loss:  0.003
# [epoch: 9, i:  1399] avg mini-batch loss:  0.002
# [epoch: 9, i:  1499] avg mini-batch loss:  0.038
# [epoch: 9, i:  1599] avg mini-batch loss:  0.066
# [epoch: 9, i:  1699] avg mini-batch loss:  0.004
# [epoch: 9, i:  1799] avg mini-batch loss:  0.003
# [epoch: 9, i:  1899] avg mini-batch loss:  0.003
# [epoch: 9, i:  1999] avg mini-batch loss:  0.029
# [epoch: 9, i:  2099] avg mini-batch loss:  0.004
# [epoch: 9, i:  2199] avg mini-batch loss:  0.002
# [epoch: 9, i:  2299] avg mini-batch loss:  0.001
# [epoch: 9, i:  2399] avg mini-batch loss:  0.001
# [epoch: 9, i:  2499] avg mini-batch loss:  0.006
# [epoch: 9, i:  2599] avg mini-batch loss:  0.002
# [epoch: 9, i:  2699] avg mini-batch loss:  0.001
# [epoch: 9, i:  2799] avg mini-batch loss:  0.026
# [epoch: 9, i:  2899] avg mini-batch loss:  0.014
# [epoch: 9, i:  2999] avg mini-batch loss:  0.003
# [epoch: 9, i:  3099] avg mini-batch loss:  0.103
# [epoch: 9, i:  3199] avg mini-batch loss:  0.005
# [epoch: 9, i:  3299] avg mini-batch loss:  0.001
# [epoch: 9, i:  3399] avg mini-batch loss:  0.001
# [epoch: 9, i:  3499] avg mini-batch loss:  0.000
# [epoch: 9, i:  3599] avg mini-batch loss:  0.000
# [epoch: 9, i:  3699] avg mini-batch loss:  0.000
# Finished Training.

# %%
# training loss curve
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# test the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for spectrograms, labels in test_loader:
        if spectrograms.shape[1] > 1:
            spectrograms = torch.mean(spectrograms, dim=1, keepdim=True)

        outputs = model(spectrograms)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# Accuracy: 79.6%
